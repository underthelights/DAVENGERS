# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

plt.style.use('seaborn')
from matplotlib import rc, font_manager
#font_path = "C:/Windows/Fonts/NanumSquareB.TTF"
#font = font_manager.FontProperties(fname=font_path).get_name()
#rc('font', family=font)


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

for i, file in enumerate(os.listdir("../../data/rename")):
    globals()[file[:2]] = pd.read_csv("../../data/rename/"+file, encoding='cp949')

# %%
t1['LG_CAT_NM'].unique()
# Out:
# array(['요식/유흥', '음/식료품', '의류/잡화', '스포츠/문화/레저', '유통', '여행/교통'],
#       dtype=object)

# %%
t1[t1['LG_CAT_NM']=='스포츠/문화/레저']
# Out:
#           YR                   MCT_NM     MCT_BRN  LG_CAT  LG_CAT_NM  MD_CAT  \
# 66      2021                       봉봉  6162974161       5  스포츠/문화/레저      14
# 67      2021                       봉봉  6162974161       5  스포츠/문화/레저      14
# 68      2021                       봉봉  6162974161       5  스포츠/문화/레저      14
# 69      2021                       봉봉  6162974161       5  스포츠/문화/레저      14
# 70      2021                       봉봉  6162974161       5  스포츠/문화/레저      14
# ...      ...                      ...         ...     ...        ...     ...
# 316137  2022   업드림 스튜디오(난산리다방  조아가지구)  7120900746       5  스포츠/문화/레저      13
# 316158  2022  코오롱인더스트리(주)FnC부문 솟솟리버스점  3688501727       5  스포츠/문화/레저      14
# 316159  2022  코오롱인더스트리(주)FnC부문 솟솟리버스점  3688501727       5  스포츠/문화/레저      14
# 316160  2022  코오롱인더스트리(주)FnC부문 솟솟리버스점  3688501727       5  스포츠/문화/레저      14
# 316161  2021   (주)플레이타임그룹 신화월드제주플레이타임  2158605260       5  스포츠/문화/레저      13
#
# ...

# %%
t4[t4.CL_NM == '기타']
# Out:
#         CL_NM        TRRSRT_NM                             ADDR       TEL_NO  \
# 0          기타        봄그리고가을리조트  제주 서귀포시 성산읍 해맞이해안로 2660 시흥근생및주택  647842211.0
# 1          기타           토스카나호텔            제주 서귀포시 용흥로66번길 158-7  647357000.0
# 2          기타          산방산탄산온천         제주 서귀포시 안덕면 사계북로41번길 192  647928300.0
# 3          기타  해비치호텔앤드리조트(섬모라)            제주 서귀포시 표선면 민속해안로 537  647808322.0
# 76         기타          산방산탄산온천         제주 서귀포시 안덕면 사계북로41번길 192  647928300.0
# ...       ...              ...                              ...          ...
# 1048368    기타             그림카페            제주 서귀포시 안덕면 녹차분재로 218  647949224.0
# 1048399    기타         오설록 티뮤지엄             제주 서귀포시 안덕면 신화역사로 15   18993929.0
# 1048400    기타     본초족욕 수목원테마파크                    제주 제주시 은수길 65  647493370.0
# 1048417    기타          토종흑염소농장         제주 서귀포시 남원읍 자배오름로 74-275  648055099.0
# 1048489    기타             그림카페            제주 서귀포시 안덕면 녹차분재로 218  647949224.0
#
# ...

# %%
t4
# Out:
#         CL_NM        TRRSRT_NM                             ADDR       TEL_NO  \
# 0          기타        봄그리고가을리조트  제주 서귀포시 성산읍 해맞이해안로 2660 시흥근생및주택  647842211.0
# 1          기타           토스카나호텔            제주 서귀포시 용흥로66번길 158-7  647357000.0
# 2          기타          산방산탄산온천         제주 서귀포시 안덕면 사계북로41번길 192  647928300.0
# 3          기타  해비치호텔앤드리조트(섬모라)            제주 서귀포시 표선면 민속해안로 537  647808322.0
# 4        레저관광            우도잠수함          제주 서귀포시 성산읍 성산등용로 112-7  647842333.0
# ...       ...              ...                              ...          ...
# 1048569  공연전시             빛의벙커          제주 서귀포시 성산읍 고성리 2039-22   15222653.0
# 1048570  공연전시             빛의벙커          제주 서귀포시 성산읍 고성리 2039-22   15222653.0
# 1048571  테마파크            스누피가든              제주 제주시 구좌읍 금백조로 930  649031111.0
# 1048572  공연전시            점보빌리지       제주 서귀포시 안덕면 평화로319번길 31-11  647921233.0
# 1048573  테마파크            스누피가든              제주 제주시 구좌읍 금백조로 930  649031111.0
#
# ...

# %%
enter_num = t4.groupby('TRRSRT_NM')['TOT_ENTRN_NMPR_CO'].sum()
enter_num
# Out:
# TRRSRT_NM
# 2월22일                 10
# 감귤박물관              25151
# 건강과성박물관             1281
# 고스트타운                 41
# 고흐의 정원               245
#                    ...
# 해비치호텔앤드리조트(하노루)        4
# 허브동산                2123
# 헬로키티아일랜드            7170
# 화조원                 8077
# 환상의짜장                 84
# Name: TOT_ENTRN_NMPR_CO, Length: 125, dtype: int64

# %%
for i, j in zip(enter_num.index, enter_num.values):
    print(i, j)
# Out:
# 2월22일 10
# 감귤박물관 25151
# 건강과성박물관 1281
# 고스트타운 41
# 고흐의 정원 245
# 공룡랜드 211
# 그대나의뮤즈 911
# 그리스신화박물관 198
# 그림카페 466
# 그림포레스트 199
# 김녕요트투어 217
# 꽃썸 8
# 노리매테마파크 238
# 노형수퍼마켙 1992
# 다이나믹메이즈에피소드3 599
# 대유 ATV 수렵 사격랜드 26
# 더마파크 3080
# 더힐링타임 103
# 돈키쥬쥬 84
# 디저트카페 섬타르 19
# 디저트팩토리 6
# 마돈가 9
# 마라도가는여객선 865
# 마라도정기여객선 279
# 마라도정기여객선(운진항) 578
# 만장굴 161992
# 망고레이(섭지코지점) 110
# 망고홀릭종달점 3
# 메이즈랜드 27419
# 바다의향기 8
# 방림원 1235
# 본초족욕 수목원테마파크 745
# 봄그리고가을리조트 1506
# 봉이네해물짜장 2
# 브릭캠퍼스 1504
# 비양도 도항선 440
# 비자림 356642
# 빛의벙커 54940
# 뽀로로앤타요 테마파크 3273
# 사뿐 21
# 산방산 암벽식물지대 36575
# 산방산유람선 267
# 산방산탄산온천 1574
# 삼성혈 132
# 상효원 715
# 새별헤이요 22
# 생각하는정원 297
# 생각하는정원(분재예술원) 157
# 서귀포다이브 4
# 서귀포유람선 217
# 서귀포잠수함 2958
# 서피플 1
# 성산일출봉 297629
# 성산포유람선 992
# 세계자동차박물관 1046
# 세리월드 897
# 센트럴파크 46
# 소인국테마파크 1868
# 송악왕발통 27
# 송악카트체험장 307
# 쇠소깍산물관광농원 15
# 숨도박물관 103
# 스누피가든 129459
# 시크릿테마파크 2
# 신라호텔제주 뷔페 12960
# 신화테마파크제주 612
# 아이스뮤지엄 1021
# 아이스뮤지엄(수목원테마파크) 718
# 아프리카박물관 808
# 액트몬(신화월드점) 21
# 여미지식물원 10260
# 영주말가든 68
# 오늘은 녹차 족욕 2
# ...

# %%
t4.ENTRN_DE.max()
# Out:
# 20220524

# %%
t4.TRRSRT_NM.unique()
# Out:
# array(['봄그리고가을리조트', '토스카나호텔', '산방산탄산온천', '해비치호텔앤드리조트(섬모라)', '우도잠수함',
#        '스누피가든', '테디베어뮤지엄 제주', '여미지식물원', '노형수퍼마켙', '카멜리아힐', '헬로키티아일랜드',
#        '한림공원', '뽀로로앤타요 테마파크', '빛의벙커', '더마파크', '그대나의뮤즈', '메이즈랜드', '피규어뮤지엄',
#        '그림카페', '점보빌리지', '브릭캠퍼스', '망고홀릭종달점', '포니밸리 낙타테마파크', '방림원', '화조원',
#        '세계자동차박물관', '건강과성박물관', '소인국테마파크', '제주무민랜드', '아프리카박물관',
#        '다이나믹메이즈에피소드3', '고흐의 정원', '더힐링타임', '아이스뮤지엄(수목원테마파크)', '돈키쥬쥬',
#        '본초족욕 수목원테마파크', '서귀포잠수함', '제주실탄사격장', '제주레일바이크', '제주해양동물박물관',
#        '오설록 티뮤지엄', '상효원', '노리매테마파크', '중문레져UTV', '바다의향기', '마라도정기여객선(운진항)',
#        '세리월드', '마라도가는여객선', '제주민속촌', '비양도 도항선', '차귀도유람선', '허브동산',
#        '테라피샹그릴라', '숨도박물관', '김녕요트투어', '송악카트체험장', '2월22일', '영주말가든', '공룡랜드',
#        '환상의짜장', '하늘여행 행글라이더', '차귀도 달래배낚시', '제주바다체험장', '삼성혈', '유리박물관',
#        '캐릭파크', '일출랜드', '제주돌마을공원', '제주카약', '생각하는정원(분재예술원)', '성산포유람선',
#        '센트럴파크', '오늘은 녹차 족욕', '쇠소깍산물관광농원', '산방산유람선', '제주오메오메', '꽃썸',
# ...

# %%
t5[t5.CL_NM == '관광지'].AREA_NM.unique()
# Out:
# array(['산천단곰솔', '테디베어사파리 테지움', '휘닉스 르쏠레이테라피', ..., '제주공룡랜드[휴장중]',
#        '제주러브랜드[휴업중]', '플레이네이쳐'], dtype=object)

# %%
t5.CL_NM.unique()
# Out:
# array(['숙박', '음식점', '관광지', '쇼핑'], dtype=object)
