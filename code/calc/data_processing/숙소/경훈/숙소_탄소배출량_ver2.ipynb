# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

plt.style.use('seaborn')
from matplotlib import rc, font_manager
#font_path = "C:/Windows/Fonts/NanumSquareB.TTF"
#font = font_manager.FontProperties(fname=font_path).get_name()
#rc('font', family=font)


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

for i, file in enumerate(os.listdir("../../data/rename")):
    globals()[file[:2]] = pd.read_csv("../../data/rename/"+file, encoding='cp949')

# %%
t4 = pd.read_csv('../../data/juso/t4_coded.csv', index_col=0)
t5 = pd.read_csv('../../data/juso/t5_coded.csv', index_col=0)
t5
# Out:
#       CL_NM               AREA_NM                                        ADDR  \
# CL_CD
# c3       숙박   메리어트관 제주신화월드 호텔앤리조트              제주특별자치도 서귀포시 안덕면 신화역사로304번길 38
# c3       숙박            1915 지오하우스                   제주특별자치도 서귀포시 성산읍 성산등용로 14
# c3       숙박           521 게스트 하우스  제주특별자치도 제주시 애월읍 중용길 52-1 (신엄리) 521 게스트 하우스
# c3       숙박              가까이에파도소리                       제주도 제주시 외도2동 연대마을길 44
# c3       숙박              가름게스트하우스                     제주특별자치도 서귀포시 법환하로9번길 10
# ...     ...                   ...                                         ...
# c4      음식점                  흑돼지촌                     제주특별자치도 제주시 한림읍 한림상로 62
# c4      음식점            흑돼지킹생구이전문점                     제주특별자치도 제주시 도령로11길 26-9
# c4      음식점                   흑소랑                         제주특별자치도 제주시 연북로 631
# c4      음식점                 흑염소마루               제주특별자치도 서귀포시 남원읍 태위로663번길 1-1
# c4      음식점                흑한우명품관                      제주특별자치도 서귀포시 일주동로 8421
#
# ...

# %%
c3
# Out:
#                          LTNO_ADDR              ROAD_NM_ADDR  SGNG_CD  \
# 0        제주특별자치도 제주시 이도이동 1987-1번지       제주특별자치도 제주시 구남동1길 2    50110
# 1        제주특별자치도 제주시 이도이동 1986-5번지      제주특별자치도 제주시 남광로2길 48    50110
# 2          제주특별자치도 제주시 이도이동 1956번지        제주특별자치도 제주시 신설로 55    50110
# 3           제주특별자치도 제주시 이도이동 405번지        제주특별자치도 제주시 승천로 27    50110
# 4         제주특별자치도 제주시 일도이동 113-7번지       제주특별자치도 제주시 남광로 181    50110
# ...                            ...                       ...      ...
# 329360   제주특별자치도 서귀포시 동홍동 114-10번지     제주특별자치도 서귀포시 동홍중앙로 55    50130
# 329361    제주특별자치도 서귀포시 동홍동 366-3번지  제주특별자치도 서귀포시 태평로512번길 34    50130
# 329362  제주특별자치도 서귀포시 서홍동 397-143번지                         0    50130
# 329363   제주특별자치도 서귀포시 토평동 2715-2번지                         0    50130
# 329364   제주특별자치도 서귀포시 토평동 3275-7번지                         0    50130
#
#         LGDNG_CD  LTNO_ORN  LTNO_VCN    GPS_LNGTD     GPS_LTTD  USE_YR  \
# ...

# %%
t4.head()
# Out:
#   CL_NM        TRRSRT_NM                             ADDR  \
# 0    기타        봄그리고가을리조트  제주 서귀포시 성산읍 해맞이해안로 2660 시흥근생및주택
# 1    기타           토스카나호텔            제주 서귀포시 용흥로66번길 158-7
# 2    기타          산방산탄산온천         제주 서귀포시 안덕면 사계북로41번길 192
# 3    기타  해비치호텔앤드리조트(섬모라)            제주 서귀포시 표선면 민속해안로 537
# 4  레저관광            우도잠수함          제주 서귀포시 성산읍 성산등용로 112-7
#
#                ADDR_new       TEL_NO  TOT_ENTRN_NMPR_CO  SETLE_PRICE  \
# 0  제주특별자치도 서귀포시 성산읍 시흥리  647842211.0                  2        18000
# 1      제주특별자치도 서귀포시 강정동  647357000.0                  2        57230
# 2  제주특별자치도 서귀포시 안덕면 사계리  647928300.0                  5        37500
# 3  제주특별자치도 서귀포시 표선면 표선리  647808322.0                  1        30600
# 4  제주특별자치도 서귀포시 성산읍 성산리  647842333.0                  2        82400
#
#    ENTRN_DE         코드값                 코드값의미  SGNG_CD  LGDNG_CD
# 0  20220301  5013025923  제주특별자치도 서귀포시 성산읍 시흥리    50130     25923
# 1  20220301  5013011600      제주특별자치도 서귀포시 강정동    50130     11600
# ...

# %%
t5
# Out:
#       CL_CD CL_NM               AREA_NM  \
# 0        c3    숙박   메리어트관 제주신화월드 호텔앤리조트
# 1        c3    숙박            1915 지오하우스
# 2        c3    숙박           521 게스트 하우스
# 3        c3    숙박              가까이에파도소리
# 4        c3    숙박              가름게스트하우스
# ...     ...   ...                   ...
# 22215    c4   음식점                  흑돼지촌
# 22216    c4   음식점            흑돼지킹생구이전문점
# 22217    c4   음식점                   흑소랑
# 22218    c4   음식점                 흑염소마루
# 22219    c4   음식점                흑한우명품관
#
#                                              ADDR  BASE_YEAR  ALL_TOTAL_CO  \
# 0                  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38       2021            43
# 1                       제주특별자치도 서귀포시 성산읍 성산등용로 14       2021            44
# 2      제주특별자치도 제주시 애월읍 중용길 52-1 (신엄리) 521 게스트 하우스       2021            26
# 3                           제주도 제주시 외도2동 연대마을길 44       2021            21
# 4                         제주특별자치도 서귀포시 법환하로9번길 10       2021            20
# ...

# %%
t4['ADDR_new']
# Out:
# 0          제주특별자치도 서귀포시 성산읍 시흥리
# 1              제주특별자치도 서귀포시 강정동
# 2          제주특별자치도 서귀포시 안덕면 사계리
# 3          제주특별자치도 서귀포시 표선면 표선리
# 4          제주특별자치도 서귀포시 성산읍 성산리
#                    ...
# 1048569    제주특별자치도 서귀포시 성산읍 고성리
# 1048570    제주특별자치도 서귀포시 성산읍 고성리
# 1048571     제주특별자치도 제주시 구좌읍 송당리
# 1048572    제주특별자치도 서귀포시 안덕면 서광리
# 1048573     제주특별자치도 제주시 구좌읍 송당리
# Name: ADDR_new, Length: 1048574, dtype: object

# %%
t4['CL_NM'].value_counts()
# Out:
# 자연       848912
# 테마관광지     92017
# 테마파크      50734
# 공연전시      24391
# 기타        12882
# 음식점        6224
# 레저관광       5948
# 레저/체험      5860
# 문화관광        939
# 키즈          637
# 숙박           23
# 체험            7
# Name: CL_NM, dtype: int64

# %%
t4[t4['TRRSRT_NM'].str.contains('리조트|호텔')]['TRRSRT_NM'].unique()
# Out:
# array(['봄그리고가을리조트', '토스카나호텔', '해비치호텔앤드리조트(섬모라)', '해비치호텔앤드리조트(하노루)',
#        '신라호텔제주 뷔페', '해비치호텔앤드리조트 섬모라'], dtype=object)

# %%
acc = t5[t5['CL_NM']=='숙박']
acc
# Out:
#       CL_NM               AREA_NM                                        ADDR  \
# CL_CD
# c3       숙박   메리어트관 제주신화월드 호텔앤리조트              제주특별자치도 서귀포시 안덕면 신화역사로304번길 38
# c3       숙박            1915 지오하우스                   제주특별자치도 서귀포시 성산읍 성산등용로 14
# c3       숙박           521 게스트 하우스  제주특별자치도 제주시 애월읍 중용길 52-1 (신엄리) 521 게스트 하우스
# c3       숙박              가까이에파도소리                       제주도 제주시 외도2동 연대마을길 44
# c3       숙박              가름게스트하우스                     제주특별자치도 서귀포시 법환하로9번길 10
# ...     ...                   ...                                         ...
# c3       숙박                휴마루리조트                 제주특별자치도 서귀포시 중산간동로8183번길 16
# c3       숙박             흰고래게스트하우스                  제주특별자치도 서귀포시 이어도로1066번길 26
# c3       숙박              흰수염고래리조트                   제주특별자치도 제주시 애월읍 일주서로 6818
# c3       숙박        히든클리프 호텔 앤 네이쳐                      제주특별자치도 서귀포시 예래해안로 542
# c3       숙박                힐링캠프펜션                           서귀포시 남원읍 위미항구로 96
#
# ...

# %%
acc[acc['AREA_NM'].str.contains('파티')]
# Out:
# Empty DataFrame
# Columns: [CL_CD, CL_NM, AREA_NM, ADDR, BASE_YEAR, ALL_TOTAL_CO, JAN_VIEWS_CO, FEB_VIEWS_CO, MAR_VIEWS_CO, APR_VIEWS_CO, MAY_VIEWS_CO, JUN_VIEWS_CO, JULY_VIEWS_CO, AUG_VIEWS_CO, SEP_VIEWS_CO, OCT_VIEWS_CO, NOV_VIEWS_CO, DEC_VIEWS_CO]
# Index: []

# %% [markdown]
# # 각 숙소(주소)별 탄소배출량
# - 추후 지번 주소가 도로명 주소로 잘 바뀌면 데이터 추가가능

# %%
emp = 0
exi = 0
arr = pd.Series()
for i, name in zip(acc['ADDR'], acc['AREA_NM']):
    if c3.loc[c3['ROAD_NM_ADDR']==i].empty:
        emp += 1
        continue
    else:
        exi += 1
        arr[name] = c3.loc[c3['ROAD_NM_ADDR']==i, 'SUM_GRGS_DSAMT'].mean()
        print(name)
        print(c3.loc[c3['ROAD_NM_ADDR']==i, 'SUM_GRGS_DSAMT'].mean())
print(f'empty : {emp}, exist : {exi}')
# Out:
# 가산토방
# 1.2830744756999999
# 가이아호텔
# 14.726192508999997
# 간드락게스트하우스
# 0.717601752
# 갤럭시호텔 제주
# 13.335227689499998
# 갯바위펜션
# 0.045879039299999994
# 게스트하우스 클럽 제이제이
# 2.8760189675
# 골드원?호텔 & 스위트
# 8.658736179
# 골든파크호텔
# 4.675559011272727
# 굿데이 펜션
# 0.6845022122000001
# 그라벨호텔제주
# 22.74561436676471
# 그랜드 조선 제주
# 28.204512448000003
# 그랜드메르호텔
# 17.57087945
# 꿈꾸는 노마드
# 2.3913983017
# 끄라비펜션
# 2.6264351283000003
# 뉴아일랜드호텔
# 21.040388549600003
# 뉴제주호텔
# 9.949190127272727
# 늘송파크텔
# 6.733545890636363
# 다솜펜션
# 0.031565152
# 다이아몬드 호텔
# 7.552137478600001
# 담앤루펜션리조트
# 10.535440664
# 더레드관광호텔
# 11.731233063899998
# 더베이리조트
# 6.1953954402
# 더블루제주
# 8.1216623433
# 더큐브리조트 제주
# 1.1762565091
# 데이즈호텔 제주서귀포오션
# 34.76655448636364
# 도일모텔
# 3.5944175837000003
# 돈내코힐 리조트
# 9.2895729701
# 동원리조트제주
# 2.4791805360909094
# 디셈버호텔
# 1.9814243248
# 라마다 앙코르 서귀포 이스트 호텔
# 20.257060076545454
# 라마다 제주시티호텔
# 56.97158953090911
# 라마다앙코르 서귀포호텔
# 30.532018246363638
# 라마다프라자제주호텔
# 1.50750410575
# 라벤다호텔
# 3.8944497162000005
# 라자관광호텔
# ...

# %%
arr.to_csv('accom.csv')

# %% [markdown]
# # 각 숙박 업종별 탄소 배출량
# 숙박 종류 (추후 1인당 탄소 배출량으로)
# - 호텔
# - 리조트
# - 모텔
# - 펜션
# - 빌라
# - 캠핑
# - 글램핑
# - 게스트하우스

# %%
co2_arr = pd.Series()
co2_arr['호텔']=arr[arr.index.str.contains('호텔')].mean()
co2_arr['리조트']=arr[arr.index.str.contains('리조트')].mean()
co2_arr['모텔']=arr[arr.index.str.contains('모텔')].mean()
co2_arr['펜션']=arr[arr.index.str.contains('펜션')].mean()
co2_arr['빌라']=arr[arr.index.str.contains('빌라')].mean()
co2_arr['캠핑']=arr[arr.index.str.contains('캠핑')].mean()
co2_arr['글램핑']=arr[arr.index.str.contains('글램핑')].mean()
co2_arr['게스트하우스']=arr[arr.index.str.contains('게스트하우스')].mean()
co2_arr['전체']=arr.values.mean()
co2_arr
# Out:
# 호텔        30.491803
# 리조트       10.522342
# 모텔         5.320416
# 펜션         2.908605
# 빌라        34.427696
# 캠핑              NaN
# 글램핑             NaN
# 게스트하우스     2.092490
# 전체        21.437912
# dtype: float64

# %%
co2_arr.to_csv('../../data/juso/accom_total.csv')

# %%
호텔 2
리조트 2
모텔 1
펜션 1
빌라
캠핑
글램핑
게스트하우스 1
