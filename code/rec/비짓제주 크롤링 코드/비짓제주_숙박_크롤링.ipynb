# %%
import pandas as pd
import requests
import time
import re

from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# # 크롤링 & 데이터 저장

# %%
# 태그, 주소, 좋아요, 찜하기, 리뷰, 방문했어요, 조회, SNS공유

def info1():
    
    tags = driver.find_elements(By.CLASS_NAME,'tag_area')
    태그.append(tags[0].text)

    주소.append(driver.find_element(By.CLASS_NAME,'info_sub_cont').text)


    infos = driver.find_elements(By.CLASS_NAME,'appraisal_cnt')
    좋아요.append(infos[0].text)
    찜하기.append(infos[1].text)
    리뷰.append(infos[2].text)
    방문했어요.append(infos[4].text)
    조회.append(infos[5].text)
    SNS공유.append(infos[6].text)

# %%
# 우측 이용안내 박스 정보들

def info2():
    
    lst = ['소개','상세 정보','숙박 업종','등급','편의시설','기타 상세']
    lst1 = [소개, 상세정보, 숙박업종, 등급, 편의시설, 기타상세 ]
    titles = driver.find_elements(By.XPATH,'//*[@id="content"]/div[2]/div[2]/div[2]/div[2]/div[2]/div/dl/dt')
    contents = driver.find_elements(By.XPATH,'//*[@id="content"]/div[2]/div[2]/div[2]/div[2]/div[2]/div/dl/dd')

    for l in range(len(lst)):
        for k in range(len(titles)):
            if lst[l] == titles[k].text:
                lst1[l].append(contents[k].text) 

        if len(lst1[l])!=len(이름): # 해당정보 없는 경우 빈칸 입력
            lst1[l].append("")

# %%
# 주변관광지, 주변음식점

def near_places():

    # 하단에'지도/주변관광지' 클릭
    driver.find_element(By.XPATH, '//*[@id="tab2"]/h2/a/span').click()
    time.sleep(1)


    # 주변관광지 
    driver.find_element(By.XPATH, '//*[@id="stab2"]/div[1]/div[1]/ul/li[2]/a').click()
    time.sleep(1)

    cnt1 = (driver.find_element(By.XPATH, '//*[@id="stab2"]/div[1]/div[1]/ul/li[2]/a')).text
    cnt1 = int(re.sub(r'[^0-9]', '', cnt1)) # 숫자만 뽑아서 저장
    주변관광지개수.append(cnt1) 

    places1 = []
    for a in range(1,cnt1+1):
        places1.append(driver.find_element(By.XPATH, '//*[@id="stab2"]/div[2]/div/div[2]/ul/li['+str(a)+']/div/dl/dd/h3/a').text)
    주변관광지.append(places1)


    # 주변음식점 
    driver.find_element(By.XPATH, '//*[@id="stab2"]/div[1]/div[1]/ul/li[3]/a').click()
    time.sleep(1)

    cnt2 = (driver.find_element(By.XPATH, '//*[@id="stab2"]/div[1]/div[1]/ul/li[3]/a')).text
    cnt2 = int(re.sub(r'[^0-9]', '', cnt2)) # 숫자만 뽑아서 저장
    주변음식점개수.append(cnt2) 

    places2 = []
    for b in range(1,cnt2+1):
        places2.append(driver.find_element(By.XPATH, '//*[@id="stab2"]/div[2]/div/div[2]/ul/li['+str(b)+']/div/dl/dd/h3/a').text)
    주변음식점.append(places2)

# %%
이름 = []
지역 = []

태그 = []
주소 = []

좋아요 = []
찜하기 = []
리뷰 = []
방문했어요 = []
조회 = []
SNS공유 = []

소개 = []
상세정보 = []
숙박업종 = []
등급 = []
편의시설 = []
기타상세 = []

상세텍스트 = []

주변관광지개수 = []
주변관광지 = []
주변음식점개수 = []
주변음식점 = []

# %%
driver = webdriver.Chrome('C:/Users/julie/Desktop/GROWTH/INSIGHT/chromedriver.exe')
driver.maximize_window()

for i in range(1,80): # 페이지
    
    url = "https://www.visitjeju.net/kr/detail/list?menuId=DOM_000001707000000000&cate1cd=cate0000000004#p"+str(i)+"&pageSize=12&sortListType=reviewcnt&viewType=list&isShowBtag&tag"
    driver.get(url) # url 로 이동
    
    for j in range(1,13): # 한 페이지에 숙소 12개
    
        try:

            이름.append(driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a/p[1]').text) 
            지역.append(driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a/p[2]').text) 
            
        except NoSuchElementException: 
            break 
            
            
        # 상세 페이지 클릭
        driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a').click()
        time.sleep(1)
        

        info1()
        상세텍스트.append(driver.find_elements(By.ID,'tab0')[0].text)
        info2()
        near_places()
        

        # 이전 페이지로 돌아가기

        driver.back()
        driver.back()
        time.sleep(2)

# %%
df = pd.DataFrame({"이름":이름, "지역":지역, "태그":태그, "주소":주소, "좋아요":좋아요, "찜하기":찜하기, "리뷰":리뷰,
                    "방문했어요":방문했어요, "조회":조회, "SNS공유":SNS공유, "소개":소개, "상세정보":상세정보, "숙박업종":숙박업종,
                    "등급":등급, "편의시설":편의시설,"기타상세":기타상세,"상세텍스트":상세텍스트,"주변관광지개수":주변관광지개수,
                  "주변관광지":주변관광지,"주변음식점개수":주변음식점개수,"주변음식점":주변음식점})
df

# %%
df.to_csv('비짓제주_숙박.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# # 데이터 로딩

# %%
df = pd.read_csv('비짓제주_숙박.csv')
df
# Out:
#                                     이름            지역  \
# 0                            나미송 머무는 곳      제주시 > 애월
# 1                           해비치호텔앤드리조트     서귀포시 > 표선
# 2                               신라호텔제주     서귀포시 > 중문
# 3                              롯데호텔 제주     서귀포시 > 중문
# 4                      제주조천스위스마을게스트하우스      제주시 > 조천
# 5                                비젠빌리지      제주시 > 구좌
# 6                           제주도푸른산푸른바다      제주시 > 구좌
# 7                          휘닉스 제주 섭지코지     서귀포시 > 성산
# 8                       히든클리프 호텔 앤 네이쳐  서귀포시 > 서귀포시내
# 9                             대명리조트 제주      제주시 > 조천
# 10                            서귀포KAL호텔  서귀포시 > 서귀포시내
# 11                             제주도푸른바다      제주시 > 구좌
# 12                           씨에스호텔앤리조트     서귀포시 > 중문
# 13                               객의하우스      제주시 > 한림
# 14                             금호리조트제주     서귀포시 > 남원
# 15                        수상한소금밭게스트하우스      제주시 > 구좌
# 16                               달달하우스      제주시 > 한림
# 17                            신라스테이 제주    제주시 > 제주시내
# 18                               틸다하우스      제주시 > 한경
# 19                 inn jeju 인제주 게스트하우스      제주시 > 한림
# 20                                르페도라     서귀포시 > 남원
# 21                           제주가좋아서 펜션      제주시 > 구좌
# 22                           나날 게스트하우스  서귀포시 > 서귀포시내
# 23                              캠핑트리펜션      제주시 > 애월
# 24                            롯데시티호텔제주    제주시 > 제주시내
# 25                            메종글래드 제주    제주시 > 제주시내
# 26       제주bp게스트하우스 JEJU BP GUESTHOUSE    제주시 > 제주시내
# 27                          제주부영호텔엔리조트     서귀포시 > 중문
# 28                          빠담빠담게스트하우스     서귀포시 > 성산
# 29                          오션스위츠호텔 제주    제주시 > 제주시내
# 30                                우도사랑   섬 속의 섬 > 우도
# 31                               제주해나루  서귀포시 > 서귀포시내
# 32                       켄싱턴리조트 제주 한림점      제주시 > 한림
# 33                          활엽수 게스트하우스     서귀포시 > 대정
# 34                          꽃하루방게스트하우스     서귀포시 > 성산
# 35                         라마다프라자 제주호텔    제주시 > 제주시내
# 36                             마레보 리조트      제주시 > 애월
# 37                              메종드오조락     서귀포시 > 성산
# 38                                범섬풍경  서귀포시 > 서귀포시내
# 39                             서귀포푸른바다  서귀포시 > 서귀포시내
# 40                             아름다운리조트     서귀포시 > 성산
# 41                              아이비테라스  서귀포시 > 서귀포시내
# 42                             야호비치하우스      제주시 > 조천
# 43                               오션스퀘어     서귀포시 > 성산
# 44                               오크하우스      제주시 > 애월
# 45                              제주WE호텔  서귀포시 > 서귀포시내
# 46                               제주리조트      제주시 > 애월
# 47                          롯데리조트아트빌라스     서귀포시 > 중문
# 48                      하워드존슨 제주 연동 호텔    제주시 > 제주시내
# 49                         꿈꾸는섬 게스트하우스      제주시 > 조천
# 50                               더본 호텔     서귀포시 > 중문
# 51                        더포그레이스호텔앤리조트     서귀포시 > 성산
# 52                   랜딩관 제주신화월드 호텔앤리조트     서귀포시 > 안덕
# 53                          베니키아 아이진호텔    제주시 > 제주시내
# 54                          베스트웨스턴제주호텔    제주시 > 제주시내
# 55                            블루하와이리조트      제주시 > 한림
# 56                             소풍(월정리)      제주시 > 구좌
# 57                               예이츠산장     서귀포시 > 남원
# 58                           유월그리고열두마루      제주시 > 구좌
# 59                            이디하우스n카페      제주시 > 구좌
# 60                               일레인호텔  서귀포시 > 서귀포시내
# 61                               제주인호텔    제주시 > 제주시내
# 62                 제주하이킹 INN(구덕게스트하우스)  서귀포시 > 서귀포시내
# 63                          파르나스 호텔 제주     서귀포시 > 중문
# 64                               펄리플러스    제주시 > 제주시내
# 65                                포도호텔     서귀포시 > 안덕
# 66                          플레이스 캠프 제주     서귀포시 > 성산
# 67                              하도리일번지      제주시 > 구좌
# 68                            한화리조트 제주    제주시 > 제주시내
# 69                              게으른소나기      제주시 > 구좌
# 70                              구름밭하우스      제주시 > 구좌
# 71                              넙빌레하우스     서귀포시 > 남원
# 72                            노낭게스트하우스     서귀포시 > 성산
# 73                           단추스테이 단추숲      제주시 > 한경
# 74                           대명 샤인빌리조트     서귀포시 > 표선
# 75                             더클라우드호텔     서귀포시 > 성산
# 76                            돈내코힐 리조트  서귀포시 > 서귀포시내
# 77                                동박생이      제주시 > 구좌
# 78                               두베하우스      제주시 > 구좌
# 79                               뒹글하우스      제주시 > 구좌
# 80                               드헤브펜션      제주시 > 구좌
# 81                        라마다 제주 함덕 호텔      제주시 > 조천
# 82                              내도바당펜션    제주시 > 제주시내
# 83                                 라포즈  서귀포시 > 서귀포시내
# 84                             레드우드하우스      제주시 > 구좌
# 85                               루시드봉봉     서귀포시 > 대정
# 86                                몽돌바당    제주시 > 제주시내
# 87                               미도호스텔  서귀포시 > 서귀포시내
# 88                               백패커스홈  서귀포시 > 서귀포시내
# 89   밸류호텔 서귀포(VALUE HOTEL Seogwipo JS)  서귀포시 > 서귀포시내
# 90                            베니키아호텔제주      제주시 > 애월
# 91                           봉쟈 게스트하우스    제주시 > 제주시내
# 92                                  비안    제주시 > 제주시내
# 93                               뽀요요펜션   섬 속의 섬 > 우도
# 94                          라마다 제주시티호텔    제주시 > 제주시내
# 95                            소소게스트하우스      제주시 > 애월
# 96                            스위트호텔 제주     서귀포시 > 중문
# 97                       슴게스트하우스 제주공항점    제주시 > 제주시내
# 98                              야스라기펜션      제주시 > 애월
# 99                              엠스테이호텔  서귀포시 > 서귀포시내
# 100                      연이네다락방 게스트하우스      제주시 > 구좌
# 101                           와이리조트 제주     서귀포시 > 안덕
# 102                               이런날엔      제주시 > 구좌
# 103                  제주 메이 더 호텔 카라반빌리지      제주시 > 구좌
# 104                       제주 에코 스위츠 펜션  서귀포시 > 서귀포시내
# 105                                제주락  서귀포시 > 서귀포시내
# 106                  서머셋 제주신화월드 호텔앤리조트     서귀포시 > 안덕
# 107                            제주샘모루펜션  서귀포시 > 서귀포시내
# 108                              제주에살다  서귀포시 > 서귀포시내
# 109                          제주카사블랑카펜션  서귀포시 > 서귀포시내
# 110                   제주해안휴양펜션(제주해안펜션)     서귀포시 > 안덕
# 111                                  초     서귀포시 > 성산
# 112                          코시롱게스트하우스     서귀포시 > 성산
# 113                           코즈게스트하우스     서귀포시 > 안덕
# 114                             펠리시아호텔  서귀포시 > 서귀포시내
# 115                               포구민박      제주시 > 애월
# 116                            표선이레하우스     서귀포시 > 표선
# 117                             하바나블루스      제주시 > 한경
# 118                              하이디펜션     서귀포시 > 안덕
# 119                            협재해오름펜션      제주시 > 한림
# 120                           호텔 리젠트마린    제주시 > 제주시내
# 121                               호텔레오    제주시 > 제주시내
# 122                메리어트관 제주신화월드 호텔앤리조트     서귀포시 > 안덕
# 123                          JAY&CHLOE     서귀포시 > 대정
# 124                    JK라마다앙코르 제주연동호텔    제주시 > 제주시내
# 125                Oh! 세화! (오세화게스트하우스)      제주시 > 구좌
# 126                    UncleBORO게스트하우스      제주시 > 한경
# 127                           가까이에파도소리    제주시 > 제주시내
# 128                           갤럭시호텔 제주    제주시 > 제주시내
# 129                            건축학개론펜션     서귀포시 > 성산
# 130                           고망난돌민박가든     서귀포시 > 성산
# 131                             골든파크호텔    제주시 > 제주시내
# 132                            그랜드메르호텔  서귀포시 > 서귀포시내
# 133                         그린트리인서귀포호텔  서귀포시 > 서귀포시내
# 134                              끄라비펜션  서귀포시 > 서귀포시내
# 135                           나무사이로햇살이      제주시 > 구좌
# 136                        나무처럼 게스트하우스      제주시 > 한림
# 137                            난드르통나무집     서귀포시 > 안덕
# 138                             남촌풀하우스     서귀포시 > 표선
# 139                             노을과어울림     서귀포시 > 대정
# 140                         단빌리지게스트하우스      제주시 > 한경
# 141                     게스트하우스 클럽 제이제이     서귀포시 > 중문
# 142                                더들집      제주시 > 구좌
# 143                             더베이리조트  서귀포시 > 서귀포시내
# 144                          도시락게스트하우스     서귀포시 > 성산
# 145                            동원리조트제주  서귀포시 > 서귀포시내
# 146                            디아넥스 호텔     서귀포시 > 안덕
# 147                               디오션힐     서귀포시 > 안덕
# 148                           또랑게스트하우스    제주시 > 제주시내
# 149                        뚜르드제주게스트하우스      제주시 > 구좌
# 150                            라림부띠끄호텔     서귀포시 > 안덕
# 151                           라온호텔앤리조트      제주시 > 한림
# 152                       레프트핸더 게스트하우스      제주시 > 구좌
# 153                              단추스테이      제주시 > 한림
# 154                         루미수다게스트하우스    제주시 > 제주시내
# 155                             리치망고펜션   섬 속의 섬 > 우도
# 156                              마니주팬션    제주시 > 제주시내
# 157                             몽마르뜨펜션      제주시 > 애월
# 158                        물고기나무게스트하우스     서귀포시 > 성산
# 159                          미라클게스트하우스    제주시 > 제주시내
# 160                           미소게스트하우스    제주시 > 제주시내
# 161                              발리인제주      제주시 > 구좌
# 162                               밭담사이      제주시 > 구좌
# 163                           베이힐 풀앤빌라  서귀포시 > 서귀포시내
# 164                           보리게스트하우스      제주시 > 구좌
# 165                               로뎀펜션   섬 속의 섬 > 우도
# 166                          북마크하우스&카페     서귀포시 > 대정
# 167                             북촌플레이스      제주시 > 조천
# 168                브라운 스위트 제주 호텔 & 리조트     서귀포시 > 성산
# 169                              브릭216  서귀포시 > 서귀포시내
# 170                               블란디야  서귀포시 > 서귀포시내
# 171                            블랙스톤리조트      제주시 > 한림
# 172                               비비엔다      제주시 > 구좌
# 173                                 빌림    제주시 > 제주시내
# 174                            산토리니 펜션      제주시 > 애월
# 175                            서귀포통나무집  서귀포시 > 서귀포시내
# 176                              선샤인호텔      제주시 > 조천
# 177                               섬타임즈    제주시 > 제주시내
# 178                             성산풀하우스     서귀포시 > 성산
# 179                           소낭게스트하우스      제주시 > 구좌
# 180                             소라담하우스      제주시 > 조천
# 181                              소랑풀빌라      제주시 > 조천
# 182                               소랑호젠     서귀포시 > 남원
# 183                               소섬바당   섬 속의 섬 > 우도
# 184                          솔바람풍경소리펜션     서귀포시 > 남원
# 185                            수앤수가족호텔      제주시 > 애월
# 186                             쉴만한 물가      제주시 > 한림
# 187                              스카이워커    제주시 > 제주시내
# 188                          슬로우리제주 민박      제주시 > 애월
# 189                             씨앤관광호텔    제주시 > 제주시내
# 190                             씨엘블루호텔    제주시 > 제주시내
# 191                             씨오르리조트  서귀포시 > 서귀포시내
# 192                             아올키즈펜션     서귀포시 > 안덕
# 193                         아프리카게스트하우스      제주시 > 조천
# 194                          알랑가게스트하우스     서귀포시 > 안덕
# 195                             애월포구풍경      제주시 > 애월
# 196                          언덕위에 빨간지붕     서귀포시 > 성산
# 197                           에덴통나무빌리지      제주시 > 한경
# 198                     여울목게스트하우스(월정리)      제주시 > 구좌
# 199                               예촌민박     서귀포시 > 남원
# 200                신화관 제주신화월드 호텔 앤 리조트     서귀포시 > 안덕
# 201                             용두암빌리지    제주시 > 제주시내
# 202                               우도피아   섬 속의 섬 > 우도
# 203                       우리희망이 게스트하우스      제주시 > 조천
# 204                              위더스펜션      제주시 > 애월
# 205                              위미모루왓     서귀포시 > 남원
# 206                         유앤아이게스트하우스    제주시 > 제주시내
# 207                              제니빌펜션     서귀포시 > 남원
# 208               제이드림호텔(jdream hotel)    제주시 > 제주시내
# 209                        제주 오션팰리스 호텔  서귀포시 > 서귀포시내
# 210                           제주도 레인보우      제주시 > 구좌
# 211                             제주로얄호텔    제주시 > 제주시내
# 212                              외돌개나라  서귀포시 > 서귀포시내
# 213                          제주썬호텔&카지노    제주시 > 제주시내
# 214                              제주애단비      제주시 > 한경
# 215                             제주엠리조트  서귀포시 > 서귀포시내
# 216                           제주오리엔탈호텔    제주시 > 제주시내
# 217                            제주이야기펜션      제주시 > 애월
# 218                         중문그린힐통나무펜션  서귀포시 > 서귀포시내
# 219                              중문스테이  서귀포시 > 서귀포시내
# 220                              지니코티지      제주시 > 한경
# 221                               쫄깃센터      제주시 > 한림
# 222                           청춘게스트하우스  서귀포시 > 서귀포시내
# 223                           초원게스트하우스   섬 속의 섬 > 우도
# 224                            제주시드니호텔      제주시 > 애월
# 225                             토스카나호텔  서귀포시 > 서귀포시내
# 226                              통나무파크      제주시 > 애월
# 227                          파크 선샤인 제주  서귀포시 > 서귀포시내
# 228                               팜핑제주  서귀포시 > 서귀포시내
# 229                              퍼시픽호텔    제주시 > 제주시내
# 230                              펜션머물다  서귀포시 > 서귀포시내
# 231                               편운산장     서귀포시 > 성산
# 232                       풍경호텔(풍경관광호텔)  서귀포시 > 서귀포시내
# 233                               프레리아      제주시 > 애월
# 234                           하도하도1929      제주시 > 구좌
# 235                          하랑 게스트하우스     서귀포시 > 대정
# 236                             하얀산호민박   섬 속의 섬 > 우도
# 237                                한라궁  서귀포시 > 서귀포시내
# 238                       함덕산티아고게스트하우스      제주시 > 조천
# 239                               해바라기      제주시 > 한림
# 240                            해바라기 펜션     서귀포시 > 표선
# 241                             해변산책펜션      제주시 > 애월
# 242                              해안길펜션   섬 속의 섬 > 우도
# 243                               헤리티지      제주시 > 애월
# 244               호스텔린든(Hostel lyndon)    제주시 > 제주시내
# 245                     호텔 스카이파크 제주1호점    제주시 > 제주시내
# 246                           홍익샤모니리조트  서귀포시 > 서귀포시내
# 247                              휘슬락호텔    제주시 > 제주시내
# 248                          흰고래게스트하우스  서귀포시 > 서귀포시내
# 249                           흰수염고래리조트      제주시 > 애월
# 250                         1915 지오하우스     서귀포시 > 성산
# 251                        521 게스트 하우스      제주시 > 애월
# 252                        be Lazy B&B     서귀포시 > 남원
# 253                             BK호텔제주  서귀포시 > 서귀포시내
# 254                     cafe말/개스트하우스 말  서귀포시 > 서귀포시내
# 255                              CS빌리지      제주시 > 애월
# 256                          For 安(포안)      제주시 > 한림
# 257                               호텔난타    제주시 > 제주시내
# 258                              JJ하우스  서귀포시 > 서귀포시내
# 259                         UTS제주골프빌리지      제주시 > 애월
# 260                            ZeZuZip     서귀포시 > 성산
# 261                           가름게스트하우스  서귀포시 > 서귀포시내
# 262                            가비오타 펜션      제주시 > 구좌
# 263                               가산토방  서귀포시 > 서귀포시내
# 264                              가이아호텔    제주시 > 제주시내
# 265                              가파도민박  섬 속의 섬 > 가파도
# 266                            가파도상동펜션  섬 속의 섬 > 가파도
# 267                          간드락게스트하우스    제주시 > 제주시내
# 268                               감비나무      제주시 > 구좌
# 269                              IGH펜션      제주시 > 한경
# 270                             강정서부민박  서귀포시 > 서귀포시내
# 271                          개스트하우스 말2     서귀포시 > 안덕
# 272                              갤러리민박  섬 속의 섬 > 추차도
# 273                              갯바위펜션  서귀포시 > 서귀포시내
# 274                             거드락지민박      제주시 > 한림
# 275                            게스트하우스7    제주시 > 제주시내
# 276                               게으르게      제주시 > 조천
# 277                               고려민박  섬 속의 섬 > 추차도
# 278                             고불락하우스      제주시 > 애월
# 279                       골드원 호텔 & 스위트  서귀포시 > 서귀포시내
# 280                               골든비치    제주시 > 제주시내
# 281                            강남하우스펜션     서귀포시 > 대정
# 282                         곰씨비씨게스트하우스     서귀포시 > 안덕
# 283                               공감민박     서귀포시 > 성산
# 284                            관음사 야영장    제주시 > 제주시내
# 285                               구름비낭      제주시 > 한경
# 286                             굿데이 펜션  서귀포시 > 서귀포시내
# 287                            그라벨호텔제주    제주시 > 제주시내
# 288                          그랜드 조선 제주     서귀포시 > 중문
# 289                         그랜드 하얏트 제주    제주시 > 제주시내
# 290                               그린나래    제주시 > 제주시내
# 291                               그린민박  섬 속의 섬 > 추차도
# 292                            그린사이드펜션  서귀포시 > 서귀포시내
# 293                              그림같은집  서귀포시 > 서귀포시내
# 294                             그림같은풍경     서귀포시 > 대정
# 295                            그림그리는펜션     서귀포시 > 성산
# 296                              그림리조트    제주시 > 제주시내
# 297                              글라라의집     서귀포시 > 안덕
# 298                            금서방네이층집     서귀포시 > 안덕
# 299                            기분좋은 민박      제주시 > 구좌
# 300                            길섶나그네펜션      제주시 > 조천
# 301                        김군아미고게스트하우스      제주시 > 애월
# 302                              김녕몽생이      제주시 > 구좌
# 303                          김녕한옥 용암정원      제주시 > 구좌
# 304                            김선장네 민박  섬 속의 섬 > 추차도
# 305                             꽃머채 펜션      제주시 > 애월
# 306                            꽃향기바다소리      제주시 > 한경
# 307                               꿀잠자리     서귀포시 > 대정
# 308                            꿈꾸는 노마드  서귀포시 > 서귀포시내
# 309                              꿈꾸는바다    제주시 > 제주시내
# 310                              꿈꾸는정원      제주시 > 조천
# 311                           나무아래독채펜션      제주시 > 구좌
# 312                              나무이야기     서귀포시 > 남원
# 313                          나무이야기 하우스     서귀포시 > 표선
# 314                        나무이야기게스트하우스     서귀포시 > 남원
# 315                    나무이야기게스트하우스 2호점     서귀포시 > 남원
# 316                           까사데비발디호텔     서귀포시 > 안덕
# 317                             나바론 민박  섬 속의 섬 > 추차도
# 318                              나바론민박    제주시 > 제주시내
# 319                              나비스호텔      제주시 > 애월
# 320                              나인스파빌      제주시 > 애월
# 321                              남쪽나라빌     서귀포시 > 중문
# 322                               낭만펜션    제주시 > 제주시내
# 323                         내사랑추자야펜션민박  섬 속의 섬 > 추차도
# 324                         노닐다 게스트하우스   섬 속의 섬 > 우도
# 325                            노블렛휴양펜션     서귀포시 > 남원
# 326                           노을과 포도향기      제주시 > 애월
# 327                             노을담은뜨락     서귀포시 > 대정
# 328                            다노이커플펜션      제주시 > 구좌
# 329                               다락마마      제주시 > 구좌
# 330                               다래산장      제주시 > 애월
# 331                              다미네민박  섬 속의 섬 > 추차도
# 332                               다솜펜션  서귀포시 > 서귀포시내
# 333                              다올제민박      제주시 > 구좌
# 334                          다이브게스트하우스  서귀포시 > 서귀포시내
# 335                           다이아몬드 호텔    제주시 > 제주시내
# 336                              다인리조트      제주시 > 애월
# 337                          다인오세아노 호텔      제주시 > 애월
# 338                             달빛고운펜션      제주시 > 구좌
# 339                               달빛바다    제주시 > 제주시내
# 340                               달자펜션      제주시 > 애월
# 341                           달집게스트하우스      제주시 > 구좌
# 342                           달콤한소금만들기     서귀포시 > 안덕
# 343                              달콤한아침      제주시 > 구좌
# 344                           담앤루펜션리조트  서귀포시 > 서귀포시내
# 345                               대물민박  섬 속의 섬 > 추차도
# 346                          더 프라이빗 시로      제주시 > 한경
# 347                             더갤러리펜션      제주시 > 조천
# 348                            더그랜드섬오름  서귀포시 > 서귀포시내
# 349                            더레드관광호텔    제주시 > 제주시내
# 350                              더블루제주  서귀포시 > 서귀포시내
# 351                          더쉼팡스파&풀빌라     서귀포시 > 표선
# 352                            더아름다운펜션  서귀포시 > 서귀포시내
# 353                          더큐브리조트 제주  서귀포시 > 서귀포시내
# 354                            더하도스파빌라      제주시 > 구좌
# 355                             더하우스펜션      제주시 > 구좌
# 356                      데이즈호텔 제주서귀포오션  서귀포시 > 서귀포시내
# 357                               도도펜션     서귀포시 > 안덕
# 358                          도로시게스트하우스     서귀포시 > 성산
# 359                               도일모텔    제주시 > 제주시내
# 360                        돌고래하우스(캠핑장)  서귀포시 > 서귀포시내
# 361                               돌꽃펜션    제주시 > 제주시내
# 362                             더비비스제주  서귀포시 > 서귀포시내
# 363                             돌담한길펜션     서귀포시 > 남원
# 364                              돌집조앤정      제주시 > 구좌
# 365                               동굴민박   섬 속의 섬 > 우도
# 366                          동막골게스트하우스     서귀포시 > 안덕
# 367                             동백동산펜션      제주시 > 조천
# 368                             동복리671      제주시 > 구좌
# 369                             동산나라펜션  서귀포시 > 서귀포시내
# 370                               동양콘도      제주시 > 애월
# 371                               동일민박  섬 속의 섬 > 추차도
# 372                              동촌하우스      제주시 > 구좌
# 373                              두리안펜션     서귀포시 > 남원
# 374                               돌담민박      제주시 > 애월
# 375                               등대민박  섬 속의 섬 > 추차도
# 376                              디셈버호텔    제주시 > 제주시내
# 377                              디스이즈핫      제주시 > 구좌
# 378                               땅콩펜션   섬 속의 섬 > 우도
# 379                               또오크라      제주시 > 애월
# 380                       또올레펜션&게스트하우스      제주시 > 한경
# 381                             뜨레향 펜션     서귀포시 > 남원
# 382                             뜨리바다펜션     서귀포시 > 남원
# 383                  라마다앙코르 서귀포 이스트 호텔  서귀포시 > 서귀포시내
# 384                       라마다앙코르 서귀포호텔  서귀포시 > 서귀포시내
# 385                          라메종베니in제주     서귀포시 > 성산
# 386                               드림캐슬     서귀포시 > 남원
# 387                                라신비      제주시 > 한림
# 388                             라오체리조트  서귀포시 > 서귀포시내
# 389                             라이온힐펜션     서귀포시 > 안덕
# 390                             라자관광호텔    제주시 > 제주시내
# 391                           라파로마휴양펜션      제주시 > 한림
# 392                             라헨느리조트    제주시 > 제주시내
# 393                                란펜션    제주시 > 제주시내
# 394                               랑주호텔  서귀포시 > 서귀포시내
# 395                                런호텔  서귀포시 > 서귀포시내
# 396                            레몬이네 민박  섬 속의 섬 > 추차도
# 397                         레몬트리게스트하우스     서귀포시 > 대정
# 398                       레이크힐스 제주 리조트  서귀포시 > 서귀포시내
# 399                              레지나팬션  서귀포시 > 서귀포시내
# 400                             로그맨하우스      제주시 > 애월
# 401                               로그밸리      제주시 > 애월
# 402                           로그빌리지 펜션     서귀포시 > 표선
# 403                              로베로호텔    제주시 > 제주시내
# 404                               로즈비치      제주시 > 조천
# 405                               루시드엠     서귀포시 > 안덕
# 406                                루체빌     서귀포시 > 안덕
# 407                               루하우스     서귀포시 > 표선
# 408                         리니민박(RINY)     서귀포시 > 표선
# 409                              리버풀펜션    제주시 > 제주시내
# 410                               리틀해녀    제주시 > 제주시내
# 411                               마눌펜션      제주시 > 애월
# 412                              마당돌펜션     서귀포시 > 대정
# 413                          마라도게스트하우스  섬 속의 섬 > 마라도
# 414                              마라도별장  섬 속의 섬 > 마라도
# 415                              마레카펜션      제주시 > 한림
# 416                             마리아주펜션     서귀포시 > 성산
# 417                            마린포트리조트  서귀포시 > 서귀포시내
# 418                                 마빈      제주시 > 조천
# 419                          마이테르유스호스텔      제주시 > 애월
# 420                             마주보기펜션     서귀포시 > 성산
# 421                            리치웨이 펜션     서귀포시 > 남원
# 422                        메모리 인 제주 펜션  서귀포시 > 서귀포시내
# 423                              메이더호텔      제주시 > 구좌
# 424                              메이저호텔    제주시 > 제주시내
# 425                             메이풀하우스      제주시 > 조천
# 426                              메종드판포      제주시 > 한경
# 427                              모멘토호텔  서귀포시 > 서귀포시내
# 428                               모물펜션      제주시 > 애월
# 429                       목조 독채민박 멍3닷컴      제주시 > 조천
# 430                           몬딱게스트하우스      제주시 > 구좌
# 431                               몬딱쉼터  서귀포시 > 서귀포시내
# 432                            몬떼뷰 스테이     서귀포시 > 안덕
# 433                              머무름민박      제주시 > 구좌
# 434                              물돌이민박  섬 속의 섬 > 추차도
# 435                                물메랑      제주시 > 애월
# 436                               미도모텔     서귀포시 > 성산
# 437                              미래하우스    제주시 > 제주시내
# 438                              미르빌펜션     서귀포시 > 안덕
# 439                              미소가펜션     서귀포시 > 남원
# 440                           미쓰홍당무하우스      제주시 > 구좌
# 441                              민박바당집      제주시 > 한림
# 442                              민박집섶낭      제주시 > 한림
# 443                              민박하얀집      제주시 > 한림
# 444                                민준채      제주시 > 한림
# 445                               무이비엔      제주시 > 구좌
# 446                              밀레니엄빌  서귀포시 > 서귀포시내
# 447                               밀물민박  섬 속의 섬 > 추차도
# 448                               바다드림    제주시 > 제주시내
# 449                               바다산책     서귀포시 > 남원
# 450                              바다스케치     서귀포시 > 안덕
# 451                             바다와자전거      제주시 > 애월
# 452                            바다위올레펜션  서귀포시 > 서귀포시내
# 453                              바다의향기     서귀포시 > 대정
# 454                               바다추억    제주시 > 제주시내
# 455                               바다파파      제주시 > 조천
# 456                             바다풍경펜션      제주시 > 애월
# 457                              바다해호텔  서귀포시 > 서귀포시내
# 458                               바다향기    제주시 > 제주시내
# 459                             바닷가하얀집  서귀포시 > 서귀포시내
# 460                           바닷가하우스펜션     서귀포시 > 대정
# 461                             바당정원펜션      제주시 > 한경
# 462                            바람돌이하우스      제주시 > 구좌
# 463                          바랑쉬게스트하우스     서귀포시 > 성산
# 464                              바사팬스파      제주시 > 한경
# 465                             바산올레펜션     서귀포시 > 안덕
# 466                              바우하우스      제주시 > 구좌
# 467                               발로바쉬      제주시 > 애월
# 468                          밧돌 게스트하우스      제주시 > 구좌
# 469                               배목수집      제주시 > 구좌
# 470                              백악관민박   섬 속의 섬 > 우도
# 471                      밸류호텔 월드와이드 제주    제주시 > 제주시내
# 472                         뱅디가름게스트하우스     서귀포시 > 성산
# 473                           벙커호텔앤리조트  서귀포시 > 서귀포시내
# 474                             베누스무인텔      제주시 > 애월
# 475                          베니키아 중문호텔     서귀포시 > 중문
# 476                             별똥별채집소      제주시 > 구좌
# 477                              별마로펜션    제주시 > 제주시내
# 478                               별장민박  섬 속의 섬 > 추차도
# 479                              볕들이펜션     서귀포시 > 성산
# 480                          방울풍뎅이 하우스     서귀포시 > 남원
# 481                                보물섬     서귀포시 > 성산
# 482                            볼몽지엥하우스  서귀포시 > 서귀포시내
# 483                         봉골레 하우스 민박  섬 속의 섬 > 추차도
# 484                            봉아저씨네민박      제주시 > 한림
# 485                             부르네스테이    제주시 > 제주시내
# 486                           부영CC관광호텔     서귀포시 > 남원
# 487                              브라운캐빈      제주시 > 애월
# 488                            브리즈베이호텔     서귀포시 > 성산
# 489                             블라제리조트     서귀포시 > 표선
# 490                           블랑게스트하우스     서귀포시 > 표선
# 491                               블랙롯지     서귀포시 > 성산
# 492                             보로미 민박      제주시 > 애월
# 493                               블루마린     서귀포시 > 표선
# 494                            블루마운틴호텔     서귀포시 > 성산
# 495                               블루오션  섬 속의 섬 > 가파도
# 496                                블루펄  서귀포시 > 서귀포시내
# 497                               블룸호텔     서귀포시 > 중문
# 498                             비스타리조트    제주시 > 제주시내
# 499                         비스타케이호텔월드컵  서귀포시 > 서귀포시내
# 500                              비아 제주    제주시 > 제주시내
# 501                              비앤비호텔    제주시 > 제주시내
# 502                              비오하우스      제주시 > 구좌
# 503                              비자낭달집      제주시 > 구좌
# 504                             블랙샌즈호텔    제주시 > 제주시내
# 505                               비치조아    제주시 > 제주시내
# 506                              빌라배알로     서귀포시 > 성산
# 507                             빌라비하우스  서귀포시 > 서귀포시내
# 508                           뿌리게스트하우스      제주시 > 한경
# 509                           쁘띠제주빅터펜션    제주시 > 제주시내
# 510                             사계여행민박     서귀포시 > 안덕
# 511                              사계절민박  섬 속의 섬 > 추차도
# 512                           사랑이꽃피는민박      제주시 > 구좌
# 513                               사랑터울    제주시 > 제주시내
# 514                             사면초가펜션      제주시 > 한경
# 515                             산방산에펜션     서귀포시 > 안덕
# 516                              산방산호텔     서귀포시 > 대정
# 517                               소담펜션  서귀포시 > 서귀포시내
# 518                              소풍BnB  서귀포시 > 서귀포시내
# 519                           소풍이야기 펜션      제주시 > 애월
# 520                          솔로 게스트하우스     서귀포시 > 대정
# 521                                솔민박     서귀포시 > 표선
# 522                                송림원      제주시 > 애월
# 523                          쇠소깍섬도리왓펜션  서귀포시 > 서귀포시내
# 524                            쇠소깍올레민박  서귀포시 > 서귀포시내
# 525                           수상한집 광보네    제주시 > 제주시내
# 526                              수필하우스      제주시 > 구좌
# 527                             수하리839     서귀포시 > 성산
# 528                                소낭재      제주시 > 한림
# 529                          숲골 제주독채펜션      제주시 > 조천
# 530                        쉴띠펜션&게스트하우스     서귀포시 > 안덕
# 531                            쉼게스트하우스      제주시 > 한림
# 532                              스마일모텔    제주시 > 제주시내
# 533                             스머프하우스     서귀포시 > 중문
# 534                              스위트모텔    제주시 > 제주시내
# 535                           스카이리더스호텔    제주시 > 제주시내
# 536                             스쿠버스토리  서귀포시 > 서귀포시내
# 537                              스테이달하      제주시 > 애월
# 538                         스테이지게스트하우스      제주시 > 구좌
# 539                       스토리인제주게스트하우스    제주시 > 제주시내
# 540                             숨비아일랜드     서귀포시 > 성산
# 541                              스톤성민박  서귀포시 > 서귀포시내
# 542                        스프링데일골프앤리조트     서귀포시 > 남원
# 543                                 시땅      제주시 > 애월
# 544                                시월애     서귀포시 > 대정
# 545                              신강남모텔    제주시 > 제주시내
# 546                              신등대민박  섬 속의 섬 > 추차도
# 547                           신산게스트하우스     서귀포시 > 성산
# 548                               신촌돌집      제주시 > 조천
# 549                              신흥소시민      제주시 > 조천
# 550                             실크로드펜션    제주시 > 제주시내
# 551                               심스호텔    제주시 > 제주시내
# 552                           스토리하우스펜션    제주시 > 제주시내
# 553                            썬레이크빌제주     서귀포시 > 성산
# 554                              썬베이펜션    제주시 > 제주시내
# 555                             썬비치리조트    제주시 > 제주시내
# 556                              썬비치민박   섬 속의 섬 > 우도
# 557                             썬앤문리조트     서귀포시 > 안덕
# 558                              쏠레 민박     서귀포시 > 성산
# 559                             씨사이드아덴     서귀포시 > 중문
# 560                           씨스테이 용두암    제주시 > 제주시내
# 561                             씨스테이호텔      제주시 > 애월
# 562                              씨앤하우스      제주시 > 조천
# 563                           씨제이 관광호텔    제주시 > 제주시내
# 564                              아델리아빌    제주시 > 제주시내
# 565                           아뜨네통나무펜션      제주시 > 애월
# 566                             아띠랑스호텔     서귀포시 > 성산
# 567                           아름다운펜션민박  섬 속의 섬 > 추차도
# 568                            아리스토캣펜션    제주시 > 제주시내
# 569                               아림민박    제주시 > 제주시내
# 570                               아마빌레      제주시 > 애월
# 571                            아모렉스리조트    제주시 > 제주시내
# 572                             아모르하우스      제주시 > 구좌
# 573                              아스타호텔    제주시 > 제주시내
# 574                            아이랑키즈펜션      제주시 > 애월
# 575                        아이미 제주비치 호텔      제주시 > 조천
# 576                              아이콘민박  섬 속의 섬 > 추차도
# 577                              아이콘펜션  섬 속의 섬 > 추차도
# 578                             아인피플호텔    제주시 > 제주시내
# 579                            아침의 새소리     서귀포시 > 남원
# 580                              아침의향기  서귀포시 > 서귀포시내
# 581                               아침해변      제주시 > 조천
# 582                             아쿠아뷰티크      제주시 > 구좌
# 583                              아템파우제      제주시 > 한림
# 584                              아토하우스     서귀포시 > 남원
# 585                               아트모텔    제주시 > 제주시내
# 586                            안녕김녕sea      제주시 > 구좌
# 587                              아이존호텔    제주시 > 제주시내
# 588                             안트레 펜션      제주시 > 한림
# 589                              알로하민박      제주시 > 한림
# 590                              알앤비타운  서귀포시 > 서귀포시내
# 591                 애월해안누리펜션(구 하얀둥지펜션)      제주시 > 애월
# 592                              약천골민박  서귀포시 > 서귀포시내
# 593                           언니게스트하우스      제주시 > 구좌
# 594                             언니네여인숙      제주시 > 구좌
# 595                              엄블랑펜션     서귀포시 > 안덕
# 596                             에너벨리민박      제주시 > 한림
# 597                             에띠에리조트  서귀포시 > 서귀포시내
# 598                    에리두 Cafe n Beds  서귀포시 > 서귀포시내
# 599                      안녕프로젝트 게스트하우스      제주시 > 구좌
# 600                               에스호텔    제주시 > 제주시내
# 601                             에이지하우스     서귀포시 > 표선
# 602                             에이티눈호텔    제주시 > 제주시내
# 603                            에코그린리조트      제주시 > 한림
# 604                          에코하우스민박펜션  섬 속의 섬 > 추차도
# 605                              에쿠스모텔     서귀포시 > 안덕
# 606                              엔젤하우스      제주시 > 애월
# 607                          엘마르게스트하우스     서귀포시 > 표선
# 608                             엘쯔타운펜션      제주시 > 애월
# 609                             엠버관광호텔    제주시 > 제주시내
# 610                              엠버리조트    제주시 > 제주시내
# 611                       에바다라이더하우스.공방     서귀포시 > 성산
# 612                           엠버호텔 센트럴    제주시 > 제주시내
# 613                           여래게스트하우스      제주시 > 구좌
# 614                               여정여관  섬 속의 섬 > 추차도
# 615                              여행스케치     서귀포시 > 중문
# 616                               연지민박   섬 속의 섬 > 우도
# 617                            예다움휴양펜션    제주시 > 제주시내
# 618                          예스준게스트하우스    제주시 > 제주시내
# 619                               옛살라비      제주시 > 애월
# 620                           오누게스트하우스      제주시 > 애월
# 621                             오랑제리펜션  서귀포시 > 서귀포시내
# 622                           오렌지트리 호텔    제주시 > 제주시내
# 623                           오름게스트하우스      제주시 > 구좌
# 624                               오비두스      제주시 > 애월
# 625                              오빌하우스     서귀포시 > 남원
# 626                       오션그랜드호텔 (함덕)      제주시 > 조천
# 627                              오션스카이      제주시 > 구좌
# 628                               오션트리  서귀포시 > 서귀포시내
# 629                            오션패밀리호텔    제주시 > 제주시내
# 630                             오시록헌펜션      제주시 > 한림
# 631                   오조리비앤비(Ojoribnb)     서귀포시 > 성산
# 632                            오후여섯시펜션      제주시 > 애월
# 633                             올레관광호텔    제주시 > 제주시내
# 634                              올레리조트      제주시 > 애월
# 635                             올레요리조트  서귀포시 > 서귀포시내
# 636                             올레프로방스      제주시 > 애월
# 637                            올레해오름펜션      제주시 > 애월
# 638                              올리수펜션     서귀포시 > 중문
# 639                          와락 게스트하우스      제주시 > 구좌
# 640                         우도쉼팡게스트하우스   섬 속의 섬 > 우도
# 641                             우도올레펜션   섬 속의 섬 > 우도
# 642                         우리두리게스트하우스     서귀포시 > 표선
# 643                          우연히 행복해지다      제주시 > 한림
# 644                                월령채      제주시 > 한림
# 645                               월정소랑      제주시 > 구좌
# 646                              올레스테이  서귀포시 > 서귀포시내
# 647                             월정플레이스      제주시 > 구좌
# 648                             웨스티하우스     서귀포시 > 안덕
# 649                             유니호텔제주      제주시 > 애월
# 650                              유러하우스  서귀포시 > 서귀포시내
# 651                         유심이감성하우스민박  섬 속의 섬 > 추차도
# 652                               유창민박  섬 속의 섬 > 추차도
# 653                           유탑유블레스호텔      제주시 > 조천
# 654                               이디살래     서귀포시 > 안덕
# 655                               이레민박  섬 속의 섬 > 추차도
# 656                               이린펜션  서귀포시 > 서귀포시내
# 657                       이쁜새이쁘게노래하고펜션      제주시 > 한림
# 658                              월정에비뉴      제주시 > 구좌
# 659                              이야기별방      제주시 > 구좌
# 660                              이어도펜션    제주시 > 제주시내
# 661                            이찌마루&잠비      제주시 > 구좌
# 662                             인더 하우스      제주시 > 애월
# 663                           인추자커피앤민박  섬 속의 섬 > 추차도
# 664                             일출썬 펜션     서귀포시 > 성산
# 665                                잇츠힐      제주시 > 애월
# 666                              자넷앤캐시      제주시 > 구좌
# 667                                자연인    제주시 > 제주시내
# 668                               장원민박  서귀포시 > 서귀포시내
# 669                            저스트슬립제주     서귀포시 > 대정
# 670                                이안재      제주시 > 구좌
# 671                              절물길펜션    제주시 > 제주시내
# 672                              제니아호텔    제주시 > 제주시내
# 673                             제이앤클로이     서귀포시 > 대정
# 674                            제주 리치호텔      제주시 > 애월
# 675                             제주 벨루가     서귀포시 > 대정
# 676                             제주가온29      제주시 > 애월
# 677                  제주공항 고추잠자리 게스트하우스    제주시 > 제주시내
# 678                             제주금산펜션      제주시 > 애월
# 679                           제주나인 부띠끄  서귀포시 > 서귀포시내
# 680                            제주나인리조트    제주시 > 제주시내
# 681                           제주도통나무펜션     서귀포시 > 남원
# 682                     제주돌집2호점 (스코리아)      제주시 > 구좌
# 683                              제주디오빌  서귀포시 > 서귀포시내
# 684                              제주란펜션      제주시 > 애월
# 685                 제주를여행하는히치하이커를위한안내소    제주시 > 제주시내
# 686                          제주리시온관광호텔     서귀포시 > 표선
# 687                             제주마로펜션      제주시 > 한림
# 688                         제주마실게스트하우스    제주시 > 제주시내
# 689                              제주머무리     서귀포시 > 안덕
# 690                            제주메이플호텔    제주시 > 제주시내
# 691                           제주목화휴양펜션     서귀포시 > 남원
# 692                              제주밭담숲      제주시 > 구좌
# 693                      제주베스트힐 펜션&글램핑      제주시 > 조천
# 694                         제주부영청소년수련원     서귀포시 > 중문
# 695                             제주비치펜션      제주시 > 애월
# 696                      제주빌레성 통나무휴양펜션     서귀포시 > 성산
# 697                            제주사랑 펜션  서귀포시 > 서귀포시내
# 698                              제주산내들     서귀포시 > 표선
# 699                             제주서울민박     서귀포시 > 남원
# 700                           제주성산아일랜드     서귀포시 > 성산
# 701                               제주쉼표    제주시 > 제주시내
# 702                         제주스웨덴리조트펜션      제주시 > 한림
# 703                           제주스테이비우다  서귀포시 > 서귀포시내
# 704                           제주신신휴양펜션     서귀포시 > 안덕
# 705                              제주별바람      제주시 > 한림
# 706                              제주야자원     서귀포시 > 표선
# 707                             제주양떼목장      제주시 > 애월
# 708                              제주엔펜션     서귀포시 > 대정
# 709                               제주영숙     서귀포시 > 남원
# 710                              제주올레돔     서귀포시 > 성산
# 711                          제주올레하우스팬션      제주시 > 구좌
# 712                             제주와요펜션      제주시 > 조천
# 713                            제주우리집펜션      제주시 > 한경
# 714                            제주유스호스텔      제주시 > 애월
# 715                          제주의시간은느리다      제주시 > 구좌
# 716                               제주잔잔  서귀포시 > 서귀포시내
# 717                              제주아이니     서귀포시 > 남원
# 718                            제주토비스콘도      제주시 > 애월
# 719                          제주통나무휴양펜션     서귀포시 > 표선
# 720                             제주파도소리      제주시 > 구좌
# 721                             제주파크랜드      제주시 > 애월
# 722                            제주팔레스호텔    제주시 > 제주시내
# 723                             제주팡숑예래  서귀포시 > 서귀포시내
# 724                            제주펄관광호텔    제주시 > 제주시내
# 725                             제주펜션오다    제주시 > 제주시내
# 726                            제주펜션향림원  서귀포시 > 서귀포시내
# 727                            제주포시즌호텔    제주시 > 제주시내
# 728                            제주프렌즈펜션      제주시 > 한경
# 729                              제주코기네      제주시 > 조천
# 730                             제주하나호텔     서귀포시 > 중문
# 731                           제주항공우주호텔     서귀포시 > 안덕
# 732                            제주해조대펜션      제주시 > 한림
# 733                             제주휴리조트     서귀포시 > 성산
# 734                               조은민박  섬 속의 섬 > 추차도
# 735                             조이랜드펜션      제주시 > 애월
# 736                                조천댁      제주시 > 조천
# 737                              조천스테이      제주시 > 조천
# 738                              종달스토리      제주시 > 구좌
# 739                              중문빌리지  서귀포시 > 서귀포시내
# 740                            중문진실캠핑장     서귀포시 > 중문
# 741                          중문통나무휴양펜션  서귀포시 > 서귀포시내
# 742                             중문햇빛펜션     서귀포시 > 안덕
# 743                           중문훼미리리조트  서귀포시 > 서귀포시내
# 744                              쥬빌리펜션     서귀포시 > 안덕
# 745                              지삿개풍경  서귀포시 > 서귀포시내
# 746                               지현민박   섬 속의 섬 > 우도
# 747                               징크호텔  서귀포시 > 서귀포시내
# 748                              천상의노을      제주시 > 애월
# 749                               청재설헌  서귀포시 > 서귀포시내
# 750                             청정고을민박  섬 속의 섬 > 추차도
# 751                        체이슨호텔 더 스마일  서귀포시 > 서귀포시내
# 752                               초록새록      제주시 > 애월
# 753                              초콜릿펜션    제주시 > 제주시내
# 754                              추사랑민박  섬 속의 섬 > 추차도
# 755                              추자도민박  섬 속의 섬 > 추차도
# 756                            추자도휴양펜션  섬 속의 섬 > 추차도
# 757                            추자바다25시  섬 속의 섬 > 추차도
# 758                              추자섬민박  섬 속의 섬 > 추차도
# 759                             추자피싱랜드  섬 속의 섬 > 추차도
# 760                             취다선리조트     서귀포시 > 성산
# 761                              카사마리나     서귀포시 > 표선
# 762                              카이리조트      제주시 > 한림
# 763                               캐빈타운      제주시 > 애월
# 764                              초록하우스      제주시 > 한림
# 765                         캠퍼트리호텔앤리조트    제주시 > 제주시내
# 766                           케이관광호텔제주    제주시 > 제주시내
# 767                         켄싱턴리조트 서귀포  서귀포시 > 서귀포시내
# 768                        켄싱턴리조트 제주중문     서귀포시 > 중문
# 769                            코델리아리조트     서귀포시 > 성산
# 770                           코업시티호텔성산     서귀포시 > 성산
# 771                               코자호텔     서귀포시 > 대정
# 772                              코코스펜션      제주시 > 한림
# 773                               코쿤호텔      제주시 > 애월
# 774                           콤마게스트하우스     서귀포시 > 표선
# 775                        콤포스텔라 별들의들판      제주시 > 한림
# 776                            캐슬 드 한림      제주시 > 한림
# 777                         클럽ES리조트 제주  서귀포시 > 서귀포시내
# 778                             클로버비앤비     서귀포시 > 성산
# 779                               킴스캐빈     서귀포시 > 성산
# 780                              킹스통나무      제주시 > 애월
# 781                         타미우스골프앤빌리지      제주시 > 애월
# 782                               탐라누리     서귀포시 > 성산
# 783                               탐탐56      제주시 > 구좌
# 784                             탑팰리스호텔    제주시 > 제주시내
# 785                               태성민박  섬 속의 섬 > 추차도
# 786                              태흥리조트     서귀포시 > 남원
# 787                               태흥여관  섬 속의 섬 > 추차도
# 788                              쿨쿨하우스  서귀포시 > 서귀포시내
# 789                             테디밸리호텔     서귀포시 > 안덕
# 790                              테마하우스    제주시 > 제주시내
# 791                         토리코티지카레클린트      제주시 > 애월
# 792                             토마토하우스     서귀포시 > 성산
# 793                              토토하우스      제주시 > 애월
# 794                            투데이제주펜션  서귀포시 > 서귀포시내
# 795                              파더하우스      제주시 > 애월
# 796                              파도봐펜션     서귀포시 > 남원
# 797                           파미유스파리조트  서귀포시 > 서귀포시내
# 798                             파밀리아호텔  서귀포시 > 서귀포시내
# 799                               파인비치     서귀포시 > 남원
# 800                              파인힐호텔  서귀포시 > 서귀포시내
# 801                              파크빌리지      제주시 > 애월
# 802                            파크사이드호텔    제주시 > 제주시내
# 803                               팔도민박  섬 속의 섬 > 마라도
# 804                             팜밸리리조트  서귀포시 > 서귀포시내
# 805                               팜빌리지  서귀포시 > 서귀포시내
# 806                                 팜힐  서귀포시 > 서귀포시내
# 807                             패밀리아팬션     서귀포시 > 표선
# 808                            펜션 수망가라     서귀포시 > 남원
# 809                           펜션 에덴호스텔    제주시 > 제주시내
# 810                               펜션연리  서귀포시 > 서귀포시내
# 811                              펜션해다미    제주시 > 제주시내
# 812                              펠리스타운     서귀포시 > 성산
# 813                       포비네오두막게스트하우스      제주시 > 구좌
# 814                              포시즌펜션  서귀포시 > 서귀포시내
# 815                               포유펜션     서귀포시 > 남원
# 816                            포지타노인제주     서귀포시 > 성산
# 817                              포트애비뉴  서귀포시 > 서귀포시내
# 818                            폴라리스인제주      제주시 > 애월
# 819                             폴에이리조트  서귀포시 > 서귀포시내
# 820                            퐁낭하우스제주      제주시 > 한림
# 821                            푸르미르 펜션     서귀포시 > 성산
# 822                         풍차와노을 독채펜션      제주시 > 한경
# 823                          펜션형민박꿈꾸는숲  서귀포시 > 서귀포시내
# 824                             플라마 펜션      제주시 > 한림
# 825                              플로라펜션    제주시 > 제주시내
# 826                               피노호텔  서귀포시 > 서귀포시내
# 827                             피디스테이션      제주시 > 구좌
# 828                         피우다 게스트하우스      제주시 > 한경
# 829                               하녹펜션      제주시 > 애월
# 830                            하늘만큼땅만큼      제주시 > 애월
# 831                             하늘을달리다      제주시 > 구좌
# 832                             하늘정원펜션  서귀포시 > 서귀포시내
# 833                               하늘조각     서귀포시 > 안덕
# 834                             하늘타리펜션    제주시 > 제주시내
# 835                            프라이빗리조트  서귀포시 > 서귀포시내
# 836                          하도하도 3200      제주시 > 구좌
# 837                              하루앤하루      제주시 > 조천
# 838                         하마다 게스트하우스     서귀포시 > 남원
# 839                           하바다 통나무집     서귀포시 > 안덕
# 840                              하얀도화지  서귀포시 > 서귀포시내
# 841                               하얀언덕     서귀포시 > 표선
# 842                              하와이펜션    제주시 > 제주시내
# 843                             하이제주호텔      제주시 > 한림
# 844                       하쿠나마타타게스트하우스      제주시 > 애월
# 845                            한담풍경하우스      제주시 > 애월
# 846                            한라앤탐 펜션     서귀포시 > 남원
# 847                            하니크라운호텔    제주시 > 제주시내
# 848                                한모살      제주시 > 구좌
# 849                             함덕삼다펜션      제주시 > 조천
# 850                           핫플게스트하우스     서귀포시 > 성산
# 851                         해녀신춘자할망 민박     서귀포시 > 성산
# 852                             해담은스파빌     서귀포시 > 안덕
# 853                              해돋는마을     서귀포시 > 성산
# 854                          해뜨는집 (남원)     서귀포시 > 남원
# 855                          해뜨는집 (도두)    제주시 > 제주시내
# ...
# 618  ['순옥이네 명가', '김희선몸국', '도두해녀의집', '삼다도횟집', '닐모리동동...
# 619  ['버터모닝', '마마롱(애월)', '제주기정떡', '73st', '1950하우스'...
# 620  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 621  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 622  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 623  ['명진전복', '카페공작소', '평대성게국수', '연미정', '지붕위제주바다', ...
# 624  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '연화...
# 625                   ['바굥식당', '마로니에 미니골프카페', '레드브라운']
# 626  ['델문도', '북촌에가면', '잠녀해녀촌', '곱들락', '땅꼬분식 뷔페', '다...
# 627  ['구좌상회', '슬슬슬로우', '카페콧수염', '월정리에서브런치', '월정리갈비밥...
# 628  ['대우정', '최고집', '강정해녀의집', '제주삼다국수', '제스토리', '국수...
# 629  ['돈사돈', '순옥이네 명가', '도두해녀의집', '제주해물밥', '생돈우리', ...
# 630  ['피어22', '협재해녀의집', '수우동', '독개물항', '키친오즈', '제갈양...
# 631  ['섭지코지 해녀밥상', '맛나식당', '성산회관', '경미네집(경미휴게소)', '...
# 632  ['봄날카페', '몽상드애월(몽상)', '애월더선셋', '붉은제주', '카페콜라',...
# 633  ['제주김만복(만복이네김밥집)', '올래국수', '우진해장국', '미친부엌', '고...
# 634  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '달자...
# 635  ['최고집', '행복한시저네', '제주삼다국수', '국수냐 국밥이냐', '시스터필드...
# 636                        ['보말고을', '다가미 애월점', '윈드스톤']
# 637  ['마마롱(애월)', '제주기정떡', '1950하우스', '오메오메', '피노', ...
# 638  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 639  ['명진전복', '벵디', '카페공작소', '바보카페', '평대성게국수', '카페마...
# 640  ['하하호호(HAHAHOHO)', '섬소나이', '블랑로쉐', '우도 풍원', '봉...
# 641  ['하하호호(HAHAHOHO)', '섬소나이', '블랑로쉐', '우도 풍원', '로...
# 642  ['아모르키친', '카페희상', '섭지향', '커피가게쉬고가게', '황금무지개', ...
# 643  ['피어22', '협재해녀의집', '수우동', '독개물항', '키친오즈', '제갈양...
# 644  ['피어22', '바다를본돼지(판포점)', '제갈양', '돌하르방식당', '야자수 ...
# 645  ['구좌상회', '슬슬슬로우', '카페콧수염', '월정리에서브런치', '월정리갈비밥...
# 646  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 647  ['구좌상회', '슬슬슬로우', '카페콧수염', '월정리에서브런치', '월정리갈비밥...
# 648  ['운정이네', '피제리아3657', '중문랜드프리미엄뷔페', '산방산초가집', '...
# 649  ['요리하는 목수', '전설의마녀', '노라바', '달자카페', '제주와이너리', ...
# 650  ['대우정', '최고집', '제주삼다국수', '제스토리', '국수냐 국밥이냐', '...
# 651  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 652  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 653  ['델문도', '북촌에가면', '잠녀해녀촌', '곱들락', '땅꼬분식 뷔페', '다...
# 654  ['마노르블랑', '젠하이드어웨이', '치치퐁', '사계바다', '산방산에 옛촌',...
# 655                ['고향향토장터', '봉이네식당', '카페힐스', '추자북경']
# 656  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 657  ['명랑스낵', '피어22', '한림칼국수', '협재해녀의집', '앤트러사이트', ...
# 658  ['구좌상회', '슬슬슬로우', '민경이네어등포해녀촌', '카페콧수염', '월정리에...
# 659                                                 []
# 660  ['돈사돈', '순옥이네 명가', '도두해녀의집', '제주해물밥', '생돈우리', ...
# 661  ['구좌상회', '슬슬슬로우', '민경이네어등포해녀촌', '카페콧수염', '월정리에...
# 662  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '달자...
# 663  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 664  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 665  ['요리하는 목수', '바다속고등어쌈밥', '문동일셰프녹차고을', '전설의마녀', ...
# 666  ['명진전복', '벵디', '카페공작소', '바보카페', '평대성게국수', '카페마...
# 667  ['스시호시카이', '메종드쁘띠푸루', '도다모', '다가미(도남)', '흑소랑',...
# 668  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 669                             ['거기제주', '노을과 어울림 카페']
# 670  ['해월정', '산도롱맨도롱', '비어라운드(Be around)', '시흥해녀의집'...
# 671  ['금뽕똘향토음식점', '누리해장국', '흑돼지돈까스 뷔페 밀라네사', '현기네식당...
# 672  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 673                             ['거기제주', '노을과 어울림 카페']
# 674  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '지금이순간', '...
# 675                                                 []
# 676  ['애월더선셋', '카페콜라', '지금이순간', '호박다방', '연화키친', '제주...
# 677  ['제주김만복(만복이네김밥집)', '올래국수', '순옥이네 명가', '김지순의 낭푼...
# 678  ['연화키친', '제주샘주 영농협동조합', '어사촌도야지', '달콤한휴식', '까미...
# 679  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 680  ['돈사돈', '생돈우리', '흑돈가', '제주올레냉면 제주노형점', '늘봄흑돼지'...
# 681  ['무뚱 식도락 식당', '한라앤탐', '와랑와랑카페', '우드노트', '마므레',...
# 682  ['곰막', '쪼끌락', '김녕제주흑돼지정육점식당', '브릭스 제주', '돌코롬허니...
# 683  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 684  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '달자...
# 685  ['제주김만복(만복이네김밥집)', '올래국수', '우진해장국', '미친부엌', '고...
# 686  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 687  ['명랑스낵', '피어22', '한림칼국수', '협재해녀의집', '앤트러사이트', ...
# 688  ['제주김만복(만복이네김밥집)', '올래국수', '김지순의 낭푼밥상', '우진해장국...
# 689  ['스카이 온 파이브 다이닝', '서광춘희', '허파곶자왈화덕피자', '도희네칼국수...
# 690  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '순옥이네 명가', '...
# 691  ['무뚱 식도락 식당', '한라앤탐', '와랑와랑카페', '우드노트', '마므레',...
# 692  ['쪼끌락', '김녕제주흑돼지정육점식당', '브릭스 제주', '돌코롬허니', '우리...
# 693  ['교래손칼국수', '2093하우스', '더로맨틱', '교래흑돼지', '성미가든',...
# 694  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 695  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '지금이순간', '...
# 696  ['옛날옛적', '삼대해녀의집', '청호식당', '순덕이네해산물장터', '소라네집'...
# 697  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 698                                   ['아줄레주', '자연으로']
# 699  ['무뚱 식도락 식당', '간이옥돔역', '육값하네식육가든', '마더카페', '여행...
# 700                               ['달래식당', '리솔라 무인카페']
# 701  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '김희선몸국', '...
# 702  ['명랑스낵', '피어22', '협재해녀의집', '앤트러사이트', '수우동', '명...
# 703  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 704  ['스카이 온 파이브 다이닝', '서광춘희', '허파곶자왈화덕피자', '도희네칼국수...
# 705  ['한림칼국수', '카페콜라', '사형제횟집', '모디카', '복단지식당', '전망...
# 706                                   ['아줄레주', '자연으로']
# 707          ['어사촌도야지', '달콤한휴식', '돈카츠서황', '라운지엑스 애월점']
# 708                             ['거기제주', '노을과 어울림 카페']
# 709  ['무뚱 식도락 식당', '오끼416갤러리', '간이옥돔역', '흑염소마루', '육...
# 710  ['옛날옛적', '삼대해녀의집', '청호식당', '순덕이네해산물장터', '소라네집'...
# 711  ['구좌상회', '슬슬슬로우', '카페콧수염', '월정리에서브런치', '월정리갈비밥...
# 712  ['잠녀해녀촌', '냠냠제주', '땅꼬분식 뷔페', '다래향', '망고레이 함덕점'...
# 713  ['양가형제', '뉴저지카페', '명리동식당', '달아래팥', '피자굽는돌하르방',...
# 714                                                 []
# 715  ['명진전복', '카페공작소', '연미정', '비어라운드(Be around)', '...
# 716  ['어진이네횟집', '테라로사', '국수의전설', '하효살롱', '서귀포바당물회',...
# 717  ['델문도', '잠녀해녀촌', '냠냠제주', '곱들락', '땅꼬분식 뷔페', '다래...
# 718  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 719                        ['탐라 뚝배기', '아줄레주', '두가시가든']
# 720  ['산도롱맨도롱', '비어라운드(Be around)', '카페제주동네', '바다는안...
# 721  ['바다속고등어쌈밥', '문동일셰프녹차고을', '카이로스', '신의한모', '고마워...
# 722  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 723  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 724  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 725  ['순옥이네 명가', '김희선몸국', '도두해녀의집', '삼다도횟집', '바다풍경횟...
# 726  ['어진이네횟집', '테라로사', '국수의전설', '덕성원', '기억나는집', '쌍...
# 727  ['올래국수', '돈사돈', '순옥이네 명가', '김지순의 낭푼밥상', '도두해녀의...
# 728  ['바다를본돼지(판포점)', '울트라마린', '월령203', '늘푸른농원 연리지가든...
# 729  ['델문도', '잠녀해녀촌', '냠냠제주', '곱들락', '땅꼬분식 뷔페', '다래...
# 730  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 731  ['濟州膳제주선', '르 쉬느아 (Le Chinois)', '스카이 온 파이브 다이...
# 732  ['피어22', '협재해녀의집', '수우동', '제주맥주 양조장', '명월국민학교'...
# 733  ['옛날옛적', '삼대해녀의집', '청호식당', '순덕이네해산물장터', '소라네집'...
# 734  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 735  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 736  ['잠녀해녀촌', '냠냠제주', '땅꼬분식 뷔페', '다래향', '신촌덕인당', '...
# 737  ['델문도', '잠녀해녀촌', '냠냠제주', '땅꼬분식 뷔페', '다래향', '망고...
# 738  ['해월정', '산도롱맨도롱', '비어라운드(Be around)', '시흥해녀의집'...
# 739  ['국수바다 본점', '중문덤장', '피제리아3657', '몽키비치클럽 Monkey...
# 740                                                 []
# 741  ['수두리보말칼국수', '올레7돈 (올레칠돈)', '동도원', '주상절리회국수', ...
# 742  ['운정이네', '중문랜드프리미엄뷔페', '쉬는팡가든', '제주진미마돈가', '아뜰...
# 743  ['운정이네', '국수바다 본점', '중문덤장', '중문랜드프리미엄뷔페', '쉬는팡...
# 744  ['운정이네', '피제리아3657', '중문랜드프리미엄뷔페', '산방산초가집', '...
# 745  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 746  ['하하호호(HAHAHOHO)', '섬소나이', '블랑로쉐', '우도 풍원', '봉...
# 747  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 748  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '연화...
# 749  ['오가네전복설렁탕', '허니문하우스', '모루쿠다', '가산토방 식당', '아웃도...
# 750  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 751  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 752  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 753  ['돈사돈', '순옥이네 명가', '김지순의 낭푼밥상', '도두해녀의집', '제주해...
# 754                ['고향향토장터', '봉이네식당', '카페힐스', '추자북경']
# 755  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', '고향향토장터',...
# 756                ['고향향토장터', '봉이네식당', '카페힐스', '추자북경']
# 757  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', '고향향토장터',...
# 758  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 759                ['고향향토장터', '봉이네식당', '카페힐스', '추자북경']
# 760  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 761  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 762  ['명랑스낵', '피어22', '협재해녀의집', '앤트러사이트', '수우동', '명...
# 763  ['요리하는 목수', '바다속고등어쌈밥', '문동일셰프녹차고을', '전설의마녀', ...
# 764  ['명랑스낵', '한림칼국수', '앤트러사이트', '명월국민학교', '독개물항', ...
# 765                                         ['숲속의작은집']
# 766  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '순옥이네 명가', '...
# 767  ['대우정', '최고집', '올레7돈 (올레칠돈)', '강정해녀의집', '제주삼다국...
# 768  ['고집돌우럭(중문)', '흑돼지구이집 하영', '제주미향', '국수바다 본점', ...
# 769  ['섭지코지 해녀밥상', '맛나식당', '성산회관', '경미네집(경미휴게소)', '...
# 770  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 771  ['산방식당(모슬포본점)', '옥돔식당', '부두식당 (모슬포)', '미영이네식당'...
# 772  ['피어22', '협재해녀의집', '수우동', '제주맥주 양조장', '명월국민학교'...
# 773  ['요리하는 목수', '전설의마녀', '노라바', '달자카페', '제주와이너리', ...
# 774  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 775  ['카페콜라', '사형제횟집', '카페태희', '곽지식당', '몬스터살롱', '복단...
# 776  ['명랑스낵', '한림칼국수', '앤트러사이트', '명월국민학교', '독개물항', ...
# 777  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 778  ['해월정', '바다의집', '복자씨연탄구이', '산도롱맨도롱', '돌섬', '오조...
# 779  ['해월정', '산도롱맨도롱', '시흥해녀의집', '카페제주동네', '바다는안보여요...
# 780          ['어사촌도야지', '달콤한휴식', '돈카츠서황', '라운지엑스 애월점']
# 781                                ['새빌', '라운지엑스 애월점']
# 782                       ['어부피자', '달래식당', '리솔라 무인카페']
# 783  ['명진전복', '카페공작소', '연미정', '비어라운드(Be around)', '...
# 784  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 785  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 786  ['무뚱 식도락 식당', '간이옥돔역', '육값하네식육가든', '마더카페', '여행...
# 787  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 788  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 789  ['스카이 온 파이브 다이닝', '서광춘희', '아뜰리에 제주명월', '숨비나리카페...
# 790  ['돈사돈', '순옥이네 명가', '도두해녀의집', '제주해물밥', '생돈우리', ...
# 791  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 792  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 793                        ['보말고을', '다가미 애월점', '윈드스톤']
# 794  ['국수바다 본점', '중문덤장', '피제리아3657', '몽키비치클럽 Monkey...
# 795  ['리치망고', '고불락', '지금이순간', 'ROAD129(로드129)', '연화...
# 796  ['무뚱 식도락 식당', '우드노트', '마므레', '간이옥돔역', '흑염소마루',...
# 797  ['최고집', '행복한시저네', '제주삼다국수', '국수냐 국밥이냐', '시스터필드...
# 798  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 799  ['무뚱 식도락 식당', '오끼416갤러리', '간이옥돔역', '흑염소마루', '육...
# 800  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 801  ['바다속고등어쌈밥', '문동일셰프녹차고을', '카이로스', '신의한모', '고마워...
# 802  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '순옥이네 명가', '...
# 803  ['원조마라도짜장면', '철가방을든해녀', '해녀3대할망네', '마라도해녀촌짜장',...
# 804  ['최고집', '행복한시저네', '제주삼다국수', '국수냐 국밥이냐', '시스터필드...
# 805  ['대우정', '최고집', '서귀포네거리식당', '전원일기', '행복한시저네', '...
# 806  ['고집돌우럭(중문)', '수두리보말칼국수', '흑돼지구이집 하영', '제주미향',...
# 807                ['탐라 뚝배기', '아줄레주', '두가시가든', '옵써빵집']
# 808                                           ['수망일기']
# 809  ['제주김만복(만복이네김밥집)', '순옥이네 명가', '우진해장국', '김희선몸국'...
# 810  ['국수바다 본점', '중문덤장', '피제리아3657', '몽키비치클럽 Monkey...
# 811  ['제주김만복(만복이네김밥집)', '순옥이네 명가', '우진해장국', '미친부엌',...
# 812  ['맛나식당', '해월정', '성산회관', '경미네집(경미휴게소)', '바다의집',...
# 813  ['구좌상회', '슬슬슬로우', '카페콧수염', '월정리에서브런치', '월정리갈비밥...
# 814  ['오가네전복설렁탕', '허니문하우스', '모루쿠다', '가산토방 식당', '아웃도...
# 815  ['무뚱 식도락 식당', '우드노트', '오끼416갤러리', '마므레', '흑염소마...
# 816  ['명품한라봉아이스크림', '돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어...
# 817  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 818  ['모리노아루요', '카이로스', '소길역', '올레산야초', '제주기정떡', '1...
# 819  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 820  ['명랑스낵', '한림칼국수', '앤트러사이트', '카페콜라', '사형제횟집', '...
# 821  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 822  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 823  ['최고집', '서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍...
# 824  ['명랑스낵', '한림칼국수', '앤트러사이트', '명월국민학교', '독개물항', ...
# 825  ['돈사돈', '순옥이네 명가', '도두해녀의집', '제주해물밥', '생돈우리', ...
# 826  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 827  ['명진전복', '벵디', '카페공작소', '바보카페', '평대성게국수', '카페마...
# 828  ['제주맥주 양조장', '뉴저지카페', '명리동식당', '유람위드북스', '몽생이'...
# 829  ['제주해물밥', '바다속고등어쌈밥', '문동일셰프녹차고을', '신의한모', '고마...
# 830  ['요리하는 목수', '바다속고등어쌈밥', '문동일셰프녹차고을', '전설의마녀', ...
# 831  ['카페공작소', '비어라운드(Be around)', '얌얌돈까스', '나나이로 아...
# 832  ['어진이네횟집', '테라로사', '국수의전설', '덕성원', '기억나는집', '쌍...
# 833  ['마노르블랑', '젠하이드어웨이', '치치퐁', '사계바다', '산방산에 옛촌',...
# 834  ['제주해물밥', '바다속고등어쌈밥', '문동일셰프녹차고을', '신의한모', '고마...
# 835  ['최고집', '서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍...
# 836  ['명진전복', '벵디', '카페공작소', '평대성게국수', '카페마니', '톰톰카...
# 837  ['잠녀해녀촌', '냠냠제주', '땅꼬분식 뷔페', '다래향', '망고레이 함덕점'...
# 838  ['무뚱 식도락 식당', '오끼416갤러리', '간이옥돔역', '흑염소마루', '육...
# 839  ['운정이네', '피제리아3657', '산방산초가집', '제주진미마돈가', '중앙식...
# 840  ['고집돌우럭(중문)', '흑돼지구이집 하영', '제주미향', '국수바다 본점', ...
# 841  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 842  ['올래국수', '순옥이네 명가', '김지순의 낭푼밥상', '김희선몸국', '도두해...
# 843  ['명랑스낵', '피어22', '한림칼국수', '협재해녀의집', '앤트러사이트', ...
# 844  ['봄날카페', '몽상드애월(몽상)', '리치망고', '붉은제주', '고불락', '...
# 845  ['봄날카페', '몽상드애월(몽상)', '리치망고', '애월더선셋', '붉은제주',...
# 846  ['서연의집(영화 건축학개론)', '한라앤탐', '와랑와랑카페', '우드노트', '...
# 847  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 848  ['구좌상회', '슬슬슬로우', '민경이네어등포해녀촌', '카페콧수염', '월정리에...
# 849  ['델문도', '북촌에가면', '잠녀해녀촌', '곱들락', '땅꼬분식 뷔페', '다...
# 850  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 851                                                 []
# 852  ['마노르블랑', '젠하이드어웨이', '치치퐁', '사계바다', '산방산에 옛촌',...
# 853  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 854                          ['하례정원', '내창생태카페', '한라성']
# 855  ['순옥이네 명가', '김희선몸국', '도두해녀의집', '삼다도횟집', '닐모리동동...
# 856  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '순옥이네 명가', '...
# 857  ['고래라면', '카페오름', '명품한라봉아이스크림', '신산리마을카페', '아줄레...
# 858  ['요리하는 목수', '바다속고등어쌈밥', '문동일셰프녹차고을', '전설의마녀', ...
# 859  ['순옥이네 명가', '김희선몸국', '도두해녀의집', '삼다도횟집', '닐모리동동...
# 860  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 861  ['고집돌우럭(중문)', '바다다', '수두리보말칼국수', '흑돼지구이집 하영', ...
# 862  ['요리하는 목수', '바다속고등어쌈밥', '문동일셰프녹차고을', '전설의마녀', ...
# 863  ['올래국수', '순옥이네 명가', '김희선몸국', '도두해녀의집', '삼다도횟집'...
# 864  ['하하호호(HAHAHOHO)', '섬소나이', '블랑로쉐', '우도 풍원', '봉...
# 865  ['제주해물밥', '바다속고등어쌈밥', '문동일셰프녹차고을', '신의한모', '고마...
# 866  ['쪼끌락', '김녕제주흑돼지정육점식당', '브릭스 제주', '돌코롬허니', '우리...
# 867  ['명랑스낵', '피어22', '한림칼국수', '협재해녀의집', '앤트러사이트', ...
# 868  ['명랑스낵', '피어22', '한림칼국수', '협재해녀의집', '앤트러사이트', ...
# 869  ['제주해물밥', '바다속고등어쌈밥', '문동일셰프녹차고을', '신의한모', '웅스...
# 870  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '김희선몸국', '...
# 871  ['애월더선셋', '카페콜라', '사형제횟집', '호박다방', '카페태희', '곽지...
# 872  ['돌토고리족욕카페', '성신흑돼지', '골목집갈치와고등어', '탐라 뚝배기', '...
# 873  ['풍림다방', '치저스', '송당나무', '천리식당', '제주담', '으뜨미', ...
# 874  ['카페희상', '섭지향', '커피가게쉬고가게', '돌코롬봉봉', '돈돼지흑돼지',...
# 875  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 876  ['대우정', '최고집', '제주삼다국수', '제스토리', '국수냐 국밥이냐', '...
# 877  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 878  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 879  ['피제리아3657', '제주진미마돈가', '난드르깡통구이', '카페피크닉(르피크닉...
# 880  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 881  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 882         ['카페비몽', '뵈뵈', '비자림국수집', '놀놀카페', '친절한비자씨']
# 883  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 884  ['대우정', '최고집', '행복한시저네', '제주삼다국수', '제스토리', '국수...
# 885  ['어진이네횟집', '테라로사', '국수의전설', '서귀포네거리식당', '덕성원',...
# 886  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 887  ['제주김만복(만복이네김밥집)', '올래국수', '김지순의 낭푼밥상', '오라숲소리...
# 888  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '순옥이네 명가', '...
# 889  ['제주김만복(만복이네김밥집)', '올래국수', '돈사돈', '김지순의 낭푼밥상',...
# 890  ['리치망고', '요리하는 목수', '고불락', '전설의마녀', '노라바', '달자...
# 891  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 892  ['원조마라도짜장면', '철가방을든해녀', '해녀3대할망네', '마라도해녀촌짜장',...
# 893  ['추자도중앙식당', '제일식당', '커피앤빵', '오동여식당', 'BBQ치킨 추자...
# 894  ['제주김만복(만복이네김밥집)', '우진해장국', '미친부엌', '고집돌우럭(제주공...
# 895  ['서귀포네거리식당', '덕성원', '전원일기', '기억나는집', '쌍둥이횟집본점'...
# 896  ['맛나식당', '성산회관', '경미네집(경미휴게소)', '바다의집', '그리운바다...
# 897  ['서연의집(영화 건축학개론)', '바굥식당', '한라앤탐', '와랑와랑카페', '...
#
# [898 rows x 21 columns]
