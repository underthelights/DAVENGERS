# %%
import pandas as pd
import requests
import time
import re

from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# # 크롤링 & 데이터 저장

# %%
# 태그, 주소, 좋아요, 찜하기, 리뷰, 방문했어요, 조회, SNS공유

def info1():
    
    tags = driver.find_elements(By.CLASS_NAME,'tag_area')
    태그.append(tags[0].text)

    주소.append(driver.find_element(By.CLASS_NAME,'info_sub_cont').text)


    infos = driver.find_elements(By.CLASS_NAME,'appraisal_cnt')
    좋아요.append(infos[0].text)
    찜하기.append(infos[1].text)
    리뷰.append(infos[2].text)
    방문했어요.append(infos[4].text)
    조회.append(infos[5].text)
    SNS공유.append(infos[6].text)

# %%
# 우측 이용안내 박스 정보들

def info2():
    
    lst = ['소개','상세 정보','이용 시간','편의시설','기타 상세']
    lst1 = [소개, 상세정보, 이용시간, 편의시설, 기타상세 ]
    titles = driver.find_elements(By.XPATH,'//*[@id="content"]/div[2]/div[2]/div[2]/div[2]/div[2]/div/dl/dt')
    contents = driver.find_elements(By.XPATH,'//*[@id="content"]/div[2]/div[2]/div[2]/div[2]/div[2]/div/dl/dd')

    for l in range(len(lst)):
        for k in range(len(titles)):
            if lst[l] == titles[k].text:
                lst1[l].append(contents[k].text) 

        if len(lst1[l])!=len(이름): # 해당정보 없는 경우 빈칸 입력
            lst1[l].append("")

# %%
이름 = []
지역 = []

태그 = []
주소 = []

좋아요 = []
찜하기 = []
리뷰 = []
방문했어요 = []
조회 = []
SNS공유 = []

소개 = []
상세정보 = []
이용시간 = []
편의시설 = []
기타상세 = []

상세텍스트 = []

# %%
driver = webdriver.Chrome('C:/Users/julie/Desktop/GROWTH/INSIGHT/chromedriver.exe')
driver.maximize_window()

for i in range(1,139): # 페이지
    
    url = "https://www.visitjeju.net/kr/detail/list?menuId=DOM_000001719000000000&cate1cd=cate0000000005#p"+str(i)+"&pageSize=12&sortListType=reviewcnt&viewType=list&isShowBtag&tag"
    driver.get(url) # url 로 이동
    
    for j in range(1,13): # 한 페이지에 숙소 12개
    
        try:

            이름.append(driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a/p[1]').text) 
            지역.append(driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a/p[2]').text) 
            
        except NoSuchElementException: 
            break 
            
            
        # 상세 페이지 클릭
        driver.find_element(By.XPATH,'//*[@id="content"]/div/div[2]/div[5]/ul/li['+str(j)+']/dl/dt/a').click()
        time.sleep(1)
        

        info1()
        상세텍스트.append(driver.find_elements(By.ID,'tab0')[0].text)
        info2()
        

        # 이전 페이지로 돌아가기

        driver.back()
        time.sleep(2)

# %%
df = pd.DataFrame({"이름":이름, "지역":지역, "태그":태그, "주소":주소, "좋아요":좋아요, "찜하기":찜하기, "리뷰":리뷰,
                    "방문했어요":방문했어요, "조회":조회, "SNS공유":SNS공유, "소개":소개, "상세정보":상세정보, "이용시간":이용시간,
                   "편의시설":편의시설, "기타상세":기타상세, "상세텍스트":상세텍스트})
df

# %%
df.to_csv('비짓제주_음식점.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# # 데이터 로딩

# %%
df = pd.read_csv('비짓제주_음식점.csv')
df
# Out:
#                           이름               지역  \
# 0                       봄날카페         제주시 > 애월
# 1             서연의집(영화 건축학개론)        서귀포시 > 남원
# 2                       명진전복         제주시 > 구좌
# 3                  몽상드애월(몽상)         제주시 > 애월
# 4             제주김만복(만복이네김밥집)       제주시 > 제주시내
# 5                       리치망고         제주시 > 애월
# 6         르 쉬느아 (Le Chinois)        서귀포시 > 안덕
# 7                      카페공작소         제주시 > 구좌
# 8                     濟州膳제주선        서귀포시 > 안덕
# 9             하하호호(HAHAHOHO)      섬 속의 섬 > 우도
# 10                      올래국수       제주시 > 제주시내
# 11                      우유부단         제주시 > 한림
# 12             스카이 온 파이브 다이닝        서귀포시 > 안덕
# 13                     우진해장국       제주시 > 제주시내
# 14                      테라로사     서귀포시 > 서귀포시내
# 15                     마노르블랑        서귀포시 > 안덕
# 16                      가시아방        서귀포시 > 성산
# 17                      카페콜라         제주시 > 한림
# 18                      키친오즈         제주시 > 한림
# 19                       돈사돈       제주시 > 제주시내
# 20                      구좌상회         제주시 > 구좌
# 21                     애월더선셋         제주시 > 애월
# 22                       지미스      섬 속의 섬 > 우도
# 23                       델문도         제주시 > 조천
# 24                    앤트러사이트         제주시 > 한림
# 25                   우도왕자이야기      섬 속의 섬 > 우도
# 26                      명랑스낵         제주시 > 한림
# 27                       바다다     서귀포시 > 서귀포시내
# 28                       최고집     서귀포시 > 서귀포시내
# 29                      운정이네        서귀포시 > 안덕
# 30                      망고레이      섬 속의 섬 > 우도
# 31                      바보카페         제주시 > 구좌
# 32                     월정리로와         제주시 > 구좌
# 33                   순옥이네 명가       제주시 > 제주시내
# 34                      카페마니         제주시 > 구좌
# 35                       수우동         제주시 > 한림
# 36                      고래라면        서귀포시 > 성산
# 37                      블랑로쉐      섬 속의 섬 > 우도
# 38                      섬소나이      섬 속의 섬 > 우도
# 39                   요리하는 목수         제주시 > 애월
# 40              고집돌우럭(제주공항점)       제주시 > 제주시내
# 41                        벵디         제주시 > 구좌
# 42                     쉬림프박스         제주시 > 구좌
# 43                       치치퐁        서귀포시 > 안덕
# 44                      로뎀가든      섬 속의 섬 > 우도
# 45     살롱드라방 SALON de LAVANT         제주시 > 애월
# 46                     우도 풍원      섬 속의 섬 > 우도
# 47                      풍림다방         제주시 > 구좌
# 48                 고집돌우럭(중문)        서귀포시 > 중문
# 49                     국수의전설     서귀포시 > 서귀포시내
# 50                      맛나식당        서귀포시 > 성산
# 51          비어라운드(Be around)         제주시 > 구좌
# 52               산방식당(모슬포본점)        서귀포시 > 대정
# 53                      성산회관        서귀포시 > 성산
# 54                      피어22         제주시 > 한림
# 55                      평대스낵         제주시 > 구좌
# 56                     한림칼국수         제주시 > 한림
# 57               경미네집(경미휴게소)        서귀포시 > 성산
# 58                      국수마당       제주시 > 제주시내
# 59                      카페세바         제주시 > 조천
# 60                      미친부엌       제주시 > 제주시내
# 61                     슬슬슬로우         제주시 > 구좌
# 62                      유동커피     서귀포시 > 서귀포시내
# 63                    교래손칼국수         제주시 > 조천
# 64                    동복리해녀촌         제주시 > 구좌
# 65                      명당양과       제주시 > 제주시내
# 66                      바당봉봉         제주시 > 구좌
# 67                   복자씨연탄구이        서귀포시 > 성산
# 68                     사형제횟집         제주시 > 한림
# 69                 아뜰리에 제주명월        서귀포시 > 안덕
# 70                      양가형제         제주시 > 한경
# 71                   국수바다 본점     서귀포시 > 서귀포시내
# 72                       연미정         제주시 > 구좌
# 73                      웅스키친       제주시 > 제주시내
# 74                  월정리에서브런치         제주시 > 구좌
# 75                      톰톰카레         제주시 > 구좌
# 76                       해월정         제주시 > 구좌
# 77                     닐모리동동       제주시 > 제주시내
# 78                   메종드쁘띠푸루       제주시 > 제주시내
# 79                      목포고을     서귀포시 > 서귀포시내
# 80                  바다속고등어쌈밥         제주시 > 애월
# 81                  바람벽에흰당나귀         제주시 > 구좌
# 82                      서광춘희        서귀포시 > 안덕
# 83                    어진이네횟집     서귀포시 > 서귀포시내
# 84                  수두리보말칼국수        서귀포시 > 중문
# 85                 에스프레소 라운지       제주시 > 제주시내
# 86               올레7돈 (올레칠돈)     서귀포시 > 서귀포시내
# 87                      중앙식당        서귀포시 > 안덕
# 88                       쪼끌락         제주시 > 구좌
# 89                      코코마마        서귀포시 > 성산
# 90                       노라바         제주시 > 애월
# 91                      독개물항         제주시 > 한림
# 92                      레드팬더       제주시 > 제주시내
# 93                   마마롱(애월)         제주시 > 애월
# 94                      만덕이네        서귀포시 > 표선
# 95                   성읍칠십리식당        서귀포시 > 표선
# 96                 망고홀릭 제주본점       제주시 > 제주시내
# 97                    스시호시카이       제주시 > 제주시내
# 98                      신설오름       제주시 > 제주시내
# 99                     신촌덕인당         제주시 > 조천
# 100                     연화키친         제주시 > 애월
# 101                    오라숲소리       제주시 > 제주시내
# 102                   와랑와랑카페        서귀포시 > 남원
# 103                     제주미향        서귀포시 > 중문
# 104                    지금이순간         제주시 > 애월
# 105                     카이로스         제주시 > 애월
# 106                     카페쉼표         제주시 > 한림
# 107                     만선식당        서귀포시 > 대정
# 108                흑돼지구이집 하영        서귀포시 > 중문
# 109                    기억나는집     서귀포시 > 서귀포시내
# 110                    김희선몸국       제주시 > 제주시내
# 111                    낭뜰에쉼팡         제주시 > 조천
# 112               더파크뷰(신라호텔)        서귀포시 > 중문
# 113   랜딩 다이닝(Landing dining)        서귀포시 > 안덕
# 114                       리듬       제주시 > 제주시내
# 115                    북촌에가면         제주시 > 조천
# 116                     사계바다        서귀포시 > 안덕
# 117                   산도롱맨도롱         제주시 > 구좌
# 118                  쌍둥이횟집본점     서귀포시 > 서귀포시내
# 119           아라파파 a la papa       제주시 > 제주시내
# 120                    전설의마녀         제주시 > 애월
# 121             제주올레냉면 제주노형점       제주시 > 제주시내
# 122                  젠하이드어웨이        서귀포시 > 안덕
# 123                      치저스         제주시 > 구좌
# 124                     카페태희         제주시 > 애월
# 125                   협재해녀의집         제주시 > 한림
# 126                     88버거     서귀포시 > 서귀포시내
# 127                     거멍국수        서귀포시 > 안덕
# 128                      고불락         제주시 > 애월
# 129                   고서방해물탕        서귀포시 > 대정
# 130                       곰막         제주시 > 구좌
# 131                김지순의 낭푼밥상       제주시 > 제주시내
# 132                     노을언덕       제주시 > 제주시내
# 133                  다가미(도남)       제주시 > 제주시내
# 134                    레이지박스        서귀포시 > 안덕
# 135                  리치망고우도점      섬 속의 섬 > 우도
# 136                    메콩스카이       제주시 > 제주시내
# 137                    명리동식당         제주시 > 한경
# 138                문동일셰프녹차고을         제주시 > 애월
# 139                   미영이네식당        서귀포시 > 대정
# 140               민경이네어등포해녀촌         제주시 > 구좌
# 141              바다를본돼지(판포점)         제주시 > 한경
# 142                 그리운바다성산포        서귀포시 > 성산
# 143                     백양닭집       제주시 > 제주시내
# 144                     버터모닝         제주시 > 애월
# 145                  보스코화덕피자       제주시 > 제주시내
# 146                      봉끄랑      섬 속의 섬 > 우도
# 147               부두식당 (모슬포)        서귀포시 > 대정
# 148                     붉은제주         제주시 > 애월
# 149                    삼다도횟집       제주시 > 제주시내
# 150              삼대국수회관 신제주점       제주시 > 제주시내
# 151                 서귀포네거리식당     서귀포시 > 서귀포시내
# 152                   안녕육지사람      섬 속의 섬 > 우도
# 153                    앞뱅디식당       제주시 > 제주시내
# 154                   바다풍경횟집       제주시 > 제주시내
# 155                    오는정김밥     서귀포시 > 서귀포시내
# 156                     옥돔식당        서귀포시 > 대정
# 157                   우도면파전리      섬 속의 섬 > 우도
# 158                   우도해녀식당      섬 속의 섬 > 우도
# 159                     제주다음     서귀포시 > 서귀포시내
# 160                     중문덤장     서귀포시 > 서귀포시내
# 161                  철가방을든해녀     섬 속의 섬 > 마라도
# 162                 한치앞도모를바다         제주시 > 한림
# 163                허파곶자왈화덕피자        서귀포시 > 안덕
# 164                     호박다방         제주시 > 애월
# 165                    황금손가락       제주시 > 제주시내
# 166                 오가네전복설렁탕     서귀포시 > 서귀포시내
# 167                      곱들락         제주시 > 조천
# 168                     남경미락        서귀포시 > 안덕
# 169                    늘봄흑돼지       제주시 > 제주시내
# 170                    대수길다방         제주시 > 구좌
# 171                      대우정     서귀포시 > 서귀포시내
# 172                      대원가       제주시 > 제주시내
# 173                    메밀꽃차롱       제주시 > 제주시내
# 174                     모루쿠다     서귀포시 > 서귀포시내
# 175                   물꼬해녀의집      섬 속의 섬 > 우도
# 176                     바굥식당        서귀포시 > 남원
# 177                  바다는안보여요         제주시 > 구좌
# 178                가파도해물짜장짬뽕     섬 속의 섬 > 가파도
# 179                     생돈우리       제주시 > 제주시내
# 180                섭지코지 해녀밥상        서귀포시 > 성산
# 181                  성산해오름식당        서귀포시 > 성산
# 182                      소곱에         제주시 > 구좌
# 183                     어부피자        서귀포시 > 성산
# 184                  영림흑돼지가든         제주시 > 한림
# 185                     옛날옛적        서귀포시 > 성산
# 186                  올레수산회센터     서귀포시 > 서귀포시내
# 187                     와토커피        서귀포시 > 대정
# 188                     우도자연      섬 속의 섬 > 우도
# 189                   우도해광식당      섬 속의 섬 > 우도
# 190             산지물식당(건입동본점)       제주시 > 제주시내
# 191                   우수미회센타       제주시 > 제주시내
# 192              은희네해장국(일도점)       제주시 > 제주시내
# 193                     인더오조        서귀포시 > 성산
# 194                     일통이반       제주시 > 제주시내
# 195                      제스피       제주시 > 제주시내
# 196                 제주명가두루치기     서귀포시 > 서귀포시내
# 197                    제주해물밥       제주시 > 제주시내
# 198                제주흑돈세상수라간     서귀포시 > 서귀포시내
# 199                  카페 사우다드        서귀포시 > 대정
# 200                    카페루시아        서귀포시 > 안덕
# 201                 파파야 수제버거        서귀포시 > 성산
# 202                     우드스탁         제주시 > 구좌
# 203                     피노키오      섬 속의 섬 > 우도
# 204                 피자굽는돌하르방         제주시 > 한경
# 205                핀크스 비오토피아        서귀포시 > 안덕
# 206                해녀식당(동복리)         제주시 > 구좌
# 207                      화로향       제주시 > 제주시내
# 208                  회양과 국수군      섬 속의 섬 > 우도
# 209                 가파도 용궁정식        서귀포시 > 대정
# 210                  글라글라하와이        서귀포시 > 대정
# 211                    대니스카페      섬 속의 섬 > 우도
# 212                 덕승식당(구관)        서귀포시 > 대정
# 213                   도두해녀의집       제주시 > 제주시내
# 214                   평대성게국수         제주시 > 구좌
# 215             면뽑는선생 만두빚는아내         제주시 > 한림
# 216                 문어빵굽는문빵9      섬 속의 섬 > 우도
# 217                    미엘드세화         제주시 > 구좌
# 218               미풍해장국 신제주점       제주시 > 제주시내
# 219                     바다의집        서귀포시 > 성산
# 220                  비밀의숲 카페     서귀포시 > 서귀포시내
# 221                    비바리짬뽕         제주시 > 애월
# 222                      뽈살집     서귀포시 > 서귀포시내
# 223                   산방산초가집        서귀포시 > 안덕
# 224                   삼대국수회관       제주시 > 제주시내
# 225                     삼무국수       제주시 > 제주시내
# 226                  돈사촌 외도점       제주시 > 제주시내
# 227                   숙이네보리빵         제주시 > 애월
# 228                   숨비나리카페        서귀포시 > 안덕
# 229                    숨어있는집         제주시 > 조천
# 230                    쉬는팡가든     서귀포시 > 서귀포시내
# 231                   시흥해녀의집        서귀포시 > 성산
# 232                     신의한모         제주시 > 애월
# 233            아이스크림연구소(우도점)      섬 속의 섬 > 우도
# 234                    얌얌돈까스         제주시 > 구좌
# 235           엠 라운지 M Lounge        서귀포시 > 안덕
# 236                  연동마라도횟집       제주시 > 제주시내
# 237                      연이네      섬 속의 섬 > 우도
# 238                     연정식당       제주시 > 제주시내
# 239                    영주말가든       제주시 > 제주시내
# 240                    우도이야기      섬 속의 섬 > 우도
# 241                   유람위드북스         제주시 > 한경
# 242               이춘옥원조고등어쌈밥         제주시 > 애월
# 243                      제갈양         제주시 > 한림
# 244                 종종캐주얼다이닝       제주시 > 제주시내
# 245                  지붕위제주바다         제주시 > 구좌
# 246                   짬뽕에취한날       제주시 > 제주시내
# 247                     청호식당        서귀포시 > 성산
# 248                   초밥군커피씨       제주시 > 제주시내
# 249                     카페동백         제주시 > 조천
# 250                     카페오름        서귀포시 > 성산
# 251                   카페제주동네         제주시 > 구좌
# 252                   토끼와거북이       제주시 > 제주시내
# 253                    티나케이크     서귀포시 > 서귀포시내
# 254              하르방밀면(운동장점)       제주시 > 제주시내
# 255                   하얀산호식당      섬 속의 섬 > 우도
# 256                   하우스레서피         제주시 > 한림
# 257                     한라식당        서귀포시 > 표선
# 258                    헤이브라더        서귀포시 > 안덕
# 259                     현옥식당       제주시 > 제주시내
# 260                      흑소랑       제주시 > 제주시내
# 261                      카페숑        서귀포시 > 남원
# 262                 jival 지발         제주시 > 애월
# 263                 kim여사의밥상        서귀포시 > 대정
# 264                     가시식당        서귀포시 > 표선
# 265                    간이옥돔역        서귀포시 > 남원
# 266                     골막식당       제주시 > 제주시내
# 267                    교래흑돼지         제주시 > 조천
# 268                     국수장터       제주시 > 제주시내
# 269                     국시트멍       제주시 > 제주시내
# 270                     그러므로       제주시 > 제주시내
# 271                    깡촌흑돼지         제주시 > 조천
# 272                    나원회포차     서귀포시 > 서귀포시내
# 273                  2093하우스         제주시 > 조천
# 274                      남또리         제주시 > 애월
# 275                      다래향         제주시 > 조천
# 276                    다육이풍경     서귀포시 > 서귀포시내
# 277                      달사막         제주시 > 조천
# 278                     달자카페         제주시 > 애월
# 279                     대박국수       제주시 > 제주시내
# 280                      덕성원     서귀포시 > 서귀포시내
# 281                      도다모       제주시 > 제주시내
# 282                     도두반점       제주시 > 제주시내
# 283                   도희네칼국수        서귀포시 > 안덕
# 284                      돈이랑        서귀포시 > 중문
# 285                  난드르깡통구이        서귀포시 > 안덕
# 286                      떡하니         제주시 > 구좌
# 287              마로니에 미니골프카페        서귀포시 > 남원
# 288                   마린보이횟집       제주시 > 제주시내
# 289                       마쇼       제주시 > 제주시내
# 290                    만원의행복       제주시 > 제주시내
# 291               명품한라봉아이스크림        서귀포시 > 성산
# 292                      모디카         제주시 > 한림
# 293                     문화통닭        서귀포시 > 성산
# 294                     미송식탁       제주시 > 제주시내
# 295                  바다위에코끼리         제주시 > 한림
# 296                   보목해녀의집     서귀포시 > 서귀포시내
# 297                    등경돌식당        서귀포시 > 성산
# 298                    블리케이크       제주시 > 제주시내
# 299                  비포크비스트로     서귀포시 > 서귀포시내
# 300                   삼성혈해물탕       제주시 > 제주시내
# 301                     삼일식당         제주시 > 한림
# 302                     선미식당        서귀포시 > 성산
# 303                   섭지해녀의집        서귀포시 > 성산
# 304                      섭지향        서귀포시 > 표선
# 305                성산흑돼지두루치기        서귀포시 > 성산
# 306                 쇠소깍오메기식당     서귀포시 > 서귀포시내
# 307                     수복강녕       제주시 > 제주시내
# 308                순덕이네해산물장터        서귀포시 > 성산
# 309                     봉you        서귀포시 > 안덕
# 310                  신산리마을카페        서귀포시 > 성산
# 311                     아찌국밥         제주시 > 한경
# 312                       어멍         제주시 > 조천
# 313                    어반르토아       제주시 > 제주시내
# 314                      예지원     서귀포시 > 서귀포시내
# 315                옛날동문시장칼국수       제주시 > 제주시내
# 316                    올래회어촌       제주시 > 제주시내
# 317                  올랭이와물꾸럭        서귀포시 > 대정
# 318                     우도몬딱      섬 속의 섬 > 우도
# 319                 우도아름다운소풍      섬 속의 섬 > 우도
# 320                   월정리갈비밥         제주시 > 구좌
# 321                     순천미향        서귀포시 > 안덕
# 322                    이드레국수        서귀포시 > 중문
# 323                    이어도식당        서귀포시 > 표선
# 324                    일도 국수       제주시 > 제주시내
# 325                    잠녀해녀촌         제주시 > 조천
# 326                   제니스브레드     서귀포시 > 서귀포시내
# 327                     제스토리     서귀포시 > 서귀포시내
# 328                     제주오성        서귀포시 > 중문
# 329                   제주올레횟집     서귀포시 > 서귀포시내
# 330                     제주토속       제주시 > 제주시내
# 331                    제주한면가       제주시 > 제주시내
# 332                  주상절리회국수     서귀포시 > 서귀포시내
# 333                      유리네       제주시 > 제주시내
# 334                    중식당 청       제주시 > 제주시내
# 335                     짱아저씨        서귀포시 > 성산
# 336                   착한마녀김밥        서귀포시 > 성산
# 337                     천리식당       제주시 > 제주시내
# 338                     청운식당        서귀포시 > 성산
# 339                    촌촌해녀촌         제주시 > 구좌
# 340                     카페 깡         제주시 > 구좌
# 341                    카페 도두       제주시 > 제주시내
# 342              카페리(CAFERI)         제주시 > 구좌
# 343                 카페앤드효은양갱        서귀포시 > 안덕
# 344              카페피크닉(르피크닉)        서귀포시 > 안덕
# 345                중문어촌계해녀의집        서귀포시 > 중문
# 346                      타이웍       제주시 > 제주시내
# 347                     타코마씸         제주시 > 구좌
# 348                   탑동산호전복       제주시 > 제주시내
# 349                     탕궁훠궈       제주시 > 제주시내
# 350                     태광식당       제주시 > 제주시내
# 351                  평대랑 그네랑         제주시 > 구좌
# 352                   포도원흑돼지       제주시 > 제주시내
# 353                 포도호텔레스토랑        서귀포시 > 안덕
# 354                   피시야 카페         제주시 > 조천
# 355                 피제리아3657        서귀포시 > 안덕
# 356                 하노이안브라더스       제주시 > 제주시내
# 357                     한라앤탐        서귀포시 > 남원
# 358                     한성식당        서귀포시 > 성산
# 359                    해금강횟집       제주시 > 제주시내
# 360                     허벅식당         제주시 > 구좌
# 361                    호돌이식당     섬 속의 섬 > 비양도
# 362                     화진전복       제주시 > 제주시내
# 363                     73st       제주시 > 제주시내
# 364           ROAD129(로드129)         제주시 > 애월
# 365                    강해일횟집        서귀포시 > 표선
# 366                    고고리식당       제주시 > 제주시내
# 367                      고요남       제주시 > 제주시내
# 368                골목집갈치와고등어        서귀포시 > 표선
# 369                광평도새기촌 본점         제주시 > 애월
# 370                 국수냐 국밥이냐     서귀포시 > 서귀포시내
# 371                  그대와함께라면        서귀포시 > 성산
# 372                 그림상회화덕피자        서귀포시 > 표선
# 373             김녕제주흑돼지정육점식당         제주시 > 구좌
# 374                      김이박       제주시 > 제주시내
# 375                     꽁순이네         제주시 > 애월
# 376                     남양수산        서귀포시 > 성산
# 377                     남해횟집       제주시 > 제주시내
# 378                 노을해안1014         제주시 > 한경
# 379                    누리해장국       제주시 > 제주시내
# 380                       광원       제주시 > 제주시내
# 381                     달아래팥         제주시 > 한경
# 382                    달콤한휴식         제주시 > 애월
# 383                    대광장식당     서귀포시 > 서귀포시내
# 384                    대성아귀찜         제주시 > 조천
# 385                      더꽃돈         제주시 > 한림
# 386                     더클리프        서귀포시 > 중문
# 387                      더화원       제주시 > 제주시내
# 388                       덤장       제주시 > 제주시내
# 389                      데미안         제주시 > 한경
# 390                 델리지아레스토랑        서귀포시 > 중문
# 391                     도나토스         제주시 > 한림
# 392                   달마야해물탕         제주시 > 조천
# 393             돈마구이해장국(연동점)       제주시 > 제주시내
# 394                      돈향기       제주시 > 제주시내
# 395                      돌미롱       제주시 > 제주시내
# 396                     돌집식당        서귀포시 > 표선
# 397                 돌하르방 뚝배기        서귀포시 > 성산
# 398                   돌하르방식당         제주시 > 한림
# 399                      동도원     서귀포시 > 서귀포시내
# 400                     동양식당       제주시 > 제주시내
# 401                     동해미락     서귀포시 > 서귀포시내
# 402                      돼지촌       제주시 > 제주시내
# 403                     둥지식당        서귀포시 > 성산
# 404                    도토리키친       제주시 > 제주시내
# 405                      또또시     서귀포시 > 서귀포시내
# 406                     뚱보조개       제주시 > 제주시내
# 407                     띠띠빵빵      섬 속의 섬 > 우도
# 408            라지마할 RAJMAHAL       제주시 > 제주시내
# 409                    레드브라운        서귀포시 > 남원
# 410                     레드썬셋         제주시 > 구좌
# 411                레터스 투 시리얼       제주시 > 제주시내
# 412          로드3.7 (road3.7)        서귀포시 > 남원
# 413                    로이앤메이        서귀포시 > 성산
# 414              루스트플레이스 노형점       제주시 > 제주시내
# 415                 리솔라 무인카페        서귀포시 > 성산
# 416                  땅꼬분식 뷔페         제주시 > 조천
# 417                  마두천손칼국수       제주시 > 제주시내
# 418               마라도에서온자장면집        서귀포시 > 안덕
# 419                 마라도해녀촌짜장     섬 속의 섬 > 마라도
# 420                      마므레        서귀포시 > 남원
# 421                     마초그릴       제주시 > 제주시내
# 422                     만민식당         제주시 > 한림
# 423                     만세국수       제주시 > 제주시내
# 424                만세국수 삼성혈점       제주시 > 제주시내
# 425                       말이         제주시 > 구좌
# 426                     맛좋은디         제주시 > 구좌
# 427                 망고레이 함덕점         제주시 > 조천
# 428                     마더카페        서귀포시 > 남원
# 429                     메리앤폴         제주시 > 한림
# 430                   명월국민학교         제주시 > 한림
# 431                    모래비카페         제주시 > 구좌
# 432                   모리노아루요         제주시 > 애월
# 433                    모메든식당     서귀포시 > 서귀포시내
# 434                     모모제이       제주시 > 제주시내
# 435                    모슬포에서        서귀포시 > 대정
# 436                      모시란       제주시 > 제주시내
# 437                모실래기해녀해물촌      섬 속의 섬 > 우도
# 438                     몬떼마레        서귀포시 > 안덕
# 439                  무인카페 산책         제주시 > 애월
# 440                     망고봉봉        서귀포시 > 성산
# 441                   물회영해초영       제주시 > 제주시내
# 442                    미나리식당     서귀포시 > 서귀포시내
# 443                    바다어사또         제주시 > 조천
# 444                    바당꺼몬딱      섬 속의 섬 > 우도
# 445                     바당지기         제주시 > 구좌
# 446                     바람개비      섬 속의 섬 > 우도
# 447            백사장횟집(백사장회센터)        서귀포시 > 표선
# 448                    벨로인카페       제주시 > 제주시내
# 449                       벨롱         제주시 > 구좌
# 450                       보엠       제주시 > 제주시내
# 451                     보영반점         제주시 > 한림
# 452                   물질식육식당     서귀포시 > 서귀포시내
# 453                  복여네왕돈가스      섬 속의 섬 > 우도
# 454                     봉봉커피      섬 속의 섬 > 우도
# 455                    봉평메밀가       제주시 > 제주시내
# 456                      불만나         제주시 > 애월
# 457                     블랙포엠         제주시 > 조천
# 458                 비양도 올레카페     섬 속의 섬 > 비양도
# 459                       비원       제주시 > 제주시내
# 460                    빌라드아토     서귀포시 > 서귀포시내
# 461                      빌레왓        서귀포시 > 안덕
# 462                     빠라빠빵       제주시 > 제주시내
# 463                사려니숲길화덕피자         제주시 > 조천
# 464                      복댕이        서귀포시 > 성산
# 465                     산포식당        서귀포시 > 성산
# 466                 산호사 해녀의집      섬 속의 섬 > 우도
# 467                     산호풍경      섬 속의 섬 > 우도
# 468                 살랑살랑샤브샤브       제주시 > 제주시내
# 469                      상춘재         제주시 > 조천
# 470                   새벽숯불가든        서귀포시 > 성산
# 471                     색달식당     서귀포시 > 서귀포시내
# 472                    서귀포흑돈     서귀포시 > 서귀포시내
# 473                    서민흑돼지     서귀포시 > 서귀포시내
# 474                  섯동네해녀의집      섬 속의 섬 > 우도
# 475                     성미가든         제주시 > 조천
# 476             성산 고등어쌈밥 김치찜        서귀포시 > 성산
# 477                   성산진미식당        서귀포시 > 성산
# 478                    성신흑돼지        서귀포시 > 표선
# 479                      성아시         제주시 > 한림
# 480                     소라횟집         제주시 > 구좌
# 481                     소울키친        서귀포시 > 중문
# 482                      손맛촌         제주시 > 조천
# 483            송악산 엉클스 화덕 피자        서귀포시 > 대정
# 484                       쇼밥     서귀포시 > 서귀포시내
# 485                      수다뜰         제주시 > 구좌
# 486                     순정문어       제주시 > 제주시내
# 487                   쉐프 이야기       제주시 > 제주시내
# 488                  스테이위드커피        서귀포시 > 안덕
# 489                    승범이네집       제주시 > 제주시내
# 490                      시골길       제주시 > 제주시내
# 491                      신옛촌        서귀포시 > 안덕
# 492                    아뜰리에안     서귀포시 > 서귀포시내
# 493                    아모르키친        서귀포시 > 표선
# 494                      아서원     서귀포시 > 서귀포시내
# 495                   아웃도어키친     서귀포시 > 서귀포시내
# 496                  아일랜드조르바         제주시 > 구좌
# 497               아일랜드팩토리 풍류       제주시 > 제주시내
# 498                     아톰스낵         제주시 > 구좌
# 499                     스시우다       제주시 > 제주시내
# 500                   애월 고깃간         제주시 > 애월
# 501                     애월리안         제주시 > 애월
# 502                    어머니닭집        서귀포시 > 성산
# 503                    어머니몸국         제주시 > 조천
# 504                  어머니와고등어       제주시 > 제주시내
# 505              어머니의뜻을담다 단지         제주시 > 애월
# 506                     어멍횟집        서귀포시 > 성산
# 507                   어사촌도야지         제주시 > 애월
# 508                      어우늘       제주시 > 제주시내
# 509                     어전횟집        서귀포시 > 대정
# 510                      엉덩물       제주시 > 제주시내
# 511                   안거리밖거리     서귀포시 > 서귀포시내
# 512                엉클통김밥(본점)       제주시 > 제주시내
# 513              에릭스에스프레소 카페         제주시 > 구좌
# 514                     에피소드         제주시 > 한경
# 515                    엘리펀시아       제주시 > 제주시내
# 516                      연우네       제주시 > 제주시내
# 517      옐로우카페 (yellow cafe)        서귀포시 > 중문
# 518                    옛고을갈비         제주시 > 한림
# 519                      오데뜨         제주시 > 애월
# 520                    오동여식당     섬 속의 섬 > 추차도
# 521                  오드랑베이커리         제주시 > 조천
# 522                    오로라식당      섬 속의 섬 > 우도
# 523                     엉클망고      섬 속의 섬 > 우도
# 524                    오일등식당       제주시 > 제주시내
# 525                  오조해녀의 집        서귀포시 > 성산
# 526                     올댓제주       제주시 > 제주시내
# 527                     용림식당        서귀포시 > 안덕
# 528                    우무깨식당      섬 속의 섬 > 우도
# 529                     우정횟집       제주시 > 제주시내
# 530                     원앤온리        서귀포시 > 안덕
# 531                   월드컵흑돼지     서귀포시 > 서귀포시내
# 532                     월리월리         제주시 > 구좌
# 533                     월척수산       제주시 > 제주시내
# 534                     웬드구니        서귀포시 > 안덕
# 535                    오르다키친         제주시 > 애월
# 536                이성필 커피볶는집       제주시 > 제주시내
# 537               이어도전복해물전문점     서귀포시 > 서귀포시내
# 538                     인어공주      섬 속의 섬 > 우도
# 539                 일출봉쑥빵보리빵        서귀포시 > 성산
# 540                    장승포식당        서귀포시 > 성산
# 541                   저스트쉬림프         제주시 > 애월
# 542                저팔계깡통연탄구이         제주시 > 조천
# 543                     전원일기     서귀포시 > 서귀포시내
# 544                정봉자커피 봉개점       제주시 > 제주시내
# 545                    제대가는길       제주시 > 제주시내
# 546                    제라한보쌈       제주시 > 제주시내
# 547                     유스커피       제주시 > 제주시내
# 548                 제주 강남해물탕        서귀포시 > 대정
# 549                    제주 어가       제주시 > 제주시내
# 550                    제주뚝배기        서귀포시 > 성산
# 551                 제주맥주 양조장         제주시 > 한림
# 552                   제주삼다국수     서귀포시 > 서귀포시내
# 553                  제주시 새우리       제주시 > 제주시내
# 554                    제주이야기         제주시 > 구좌
# 555                 제주중문수제맥주        서귀포시 > 중문
# 556                  제주진미마돈가        서귀포시 > 안덕
# 557                      제주틈         제주시 > 한림
# 558                    중문대들보        서귀포시 > 중문
# 559                     제원분식       제주시 > 제주시내
# 560               중문수두리보말칼국수        서귀포시 > 중문
# 561                  중문자연산횟집        서귀포시 > 중문
# 562                  진대감12제주       제주시 > 제주시내
# 563                  창천삼거리식당        서귀포시 > 안덕
# 564                    청도해물탕       제주시 > 제주시내
# 565                  추자도중앙식당     섬 속의 섬 > 추차도
# 566                       춘희         제주시 > 구좌
# 567                      칠사돈       제주시 > 제주시내
# 568                      카카듀       제주시 > 제주시내
# 569                     카페백퍼         제주시 > 애월
# 570                     카페소금         제주시 > 애월
# 571                    중문솥뚜껑        서귀포시 > 중문
# 572                     카페코지        서귀포시 > 성산
# 573                    카페콧수염         제주시 > 구좌
# 574                   카페헤밍웨이         제주시 > 한림
# 575                 커피가게쉬고가게        서귀포시 > 표선
# 576                      컬쳐드       제주시 > 제주시내
# 577                   코코리파이프         제주시 > 애월
# 578                     코코분식       제주시 > 제주시내
# 579                     키아스마        서귀포시 > 남원
# 580                    킴스커틀렛       제주시 > 제주시내
# 581                      탐라면         제주시 > 애월
# 582                      탑부평       제주시 > 제주시내
# 583                    카페이피엘        서귀포시 > 남원
# 584                     팜알로하     서귀포시 > 서귀포시내
# 585                     픽스커피       제주시 > 제주시내
# 586                    하와유제주         제주시 > 애월
# 587                  하와이새우트럭       제주시 > 제주시내
# 588                한라산빵 1950       제주시 > 제주시내
# 589                     한라통닭     서귀포시 > 서귀포시내
# 590                   한마음돈가돈       제주시 > 제주시내
# 591                 한우네백년해장국       제주시 > 제주시내
# 592                    해뜨는식당        서귀포시 > 성산
# 593                     해적카페      섬 속의 섬 > 우도
# 594                  햇살가득돌담집         제주시 > 조천
# 595                     행복미가       제주시 > 제주시내
# 596                   행복한시저네     서귀포시 > 서귀포시내
# 597                    헬로우우도      섬 속의 섬 > 우도
# 598                  협재삼춘네횟집         제주시 > 한림
# 599                 홍돈깡통연탄구이         제주시 > 한림
# 600                    황토기와집     서귀포시 > 서귀포시내
# 601                      흑돈향     서귀포시 > 서귀포시내
# 602                    흑돼지신화        서귀포시 > 안덕
# 603                     흑돼지촌         제주시 > 한림
# 604               흑돼지킹생구이전문점       제주시 > 제주시내
# 605                   흑한우명품관     서귀포시 > 서귀포시내
# 606                  1080칼국수       제주시 > 제주시내
# 607             24시 뼈다귀탕 제주점       제주시 > 제주시내
# 608            24시 전주명가콩나물국밥       제주시 > 제주시내
# 609               24시누름돌김치찌개       제주시 > 제주시내
# 610               24시뼈다귀탕동홍점     서귀포시 > 서귀포시내
# 611        24시얼큰시원생고기김치찌개노형점       제주시 > 제주시내
# 612             24시전주명가콩나물국밥       제주시 > 제주시내
# 613                     60빈스     서귀포시 > 서귀포시내
# 614                 And유Café         제주시 > 한림
# 615                BBQ치킨 추자점     섬 속의 섬 > 추차도
# 616             Jeju in aA카페         제주시 > 구좌
# 617                M1971엠브릿지        서귀포시 > 대정
# 618                  1950하우스         제주시 > 애월
# 619                     가든이다        서귀포시 > 중문
# 620                  가리본가 본점       제주시 > 제주시내
# 621                   가비오타카페         제주시 > 구좌
# 622                  가산토방 식당     서귀포시 > 서귀포시내
# 623                    가야아구찜       제주시 > 제주시내
# 624                      가온해        서귀포시 > 안덕
# 625                    갈치 카페        서귀포시 > 중문
# 626                     감나무집       제주시 > 제주시내
# 627                   감산우리가든        서귀포시 > 안덕
# 628                     감저카페        서귀포시 > 대정
# 629                     감초식당       제주시 > 제주시내
# 630                    S BAR        서귀포시 > 안덕
# 631                  갤러리 라운지       제주시 > 제주시내
# 632                    갯것이식당       제주시 > 제주시내
# 633                      갯마을       제주시 > 제주시내
# 634                     거기제주        서귀포시 > 대정
# 635              거부한정식(신제주점)       제주시 > 제주시내
# 636                   거인의 정원       제주시 > 제주시내
# 637                 게우지코지 카페     서귀포시 > 서귀포시내
# 638                    게판5분전     서귀포시 > 서귀포시내
# 639                      겐짱야       제주시 > 제주시내
# 640                   겹겹의 의도     서귀포시 > 서귀포시내
# 641                    경미해장국       제주시 > 제주시내
# 642                   강정해녀의집     서귀포시 > 서귀포시내
# 643                    경주네횟집       제주시 > 제주시내
# 644                      고가네        서귀포시 > 성산
# 645                     고객식당       제주시 > 제주시내
# 646                   고내촌한정식         제주시 > 애월
# 647               고래라면 신화역사점        서귀포시 > 안덕
# 648                     고로케야       제주시 > 제주시내
# 649               고마워토토 아뜰리에         제주시 > 애월
# 650                     고망딱새       제주시 > 제주시내
# 651                 고벤져스(본점)       제주시 > 제주시내
# 652                    고사리식당         제주시 > 조천
# 653                  고씨네천지국수     서귀포시 > 서귀포시내
# 654                     경성통닭     서귀포시 > 서귀포시내
# 655                   고향향토장터     섬 속의 섬 > 추차도
# 656                      곤밥2       제주시 > 제주시내
# 657                   골목카페옥수         제주시 > 애월
# 658                    공단해장국       제주시 > 제주시내
# 659                       공백         제주시 > 구좌
# 660                    공천포식당        서귀포시 > 남원
# 661                     과수원집       제주시 > 제주시내
# 662                   곽지BAR다         제주시 > 애월
# 663                     곽지식당         제주시 > 애월
# 664              구닮카페(구름을닮다)        서귀포시 > 안덕
# 665                     구면카페        서귀포시 > 표선
# 666                      고요새       제주시 > 제주시내
# 667                    국수와냉면       제주시 > 제주시내
# 668                국제부두토산품스낵       제주시 > 제주시내
# 669                     귀빈식당     섬 속의 섬 > 추차도
# 670                귤따고 레드향갈고         제주시 > 애월
# 671               귤하르방 동문시장점       제주시 > 제주시내
# 672                      그계절         제주시 > 구좌
# 673                  그때그집 함덕         제주시 > 조천
# 674                   그랜드 키친       제주시 > 제주시내
# 675                그러므로part2       제주시 > 제주시내
# 676                      그루브         제주시 > 한림
# 677                    그리다앤쿡       제주시 > 제주시내
# 678                   구이향연동점       제주시 > 제주시내
# 679                  그릴데미그라스     서귀포시 > 서귀포시내
# 680                      그옛맛       제주시 > 제주시내
# 681                      그초록         제주시 > 구좌
# 682                   금강민물장어     서귀포시 > 서귀포시내
# 683                     금능샌드         제주시 > 한림
# 684                       금보       제주시 > 제주시내
# 685                     금보가든         제주시 > 조천
# 686                 금뽕똘향토음식점       제주시 > 제주시내
# 687                    긍정동커피     서귀포시 > 서귀포시내
# 688                      길림성       제주시 > 제주시내
# 689                     길벗식당       제주시 > 제주시내
# 690                    그리트커피       제주시 > 제주시내
# 691              김명자굴국밥(성산점)        서귀포시 > 성산
# 692             김명자굴국밥(제주본점)       제주시 > 제주시내
# 693                김밥명가 서귀포점     서귀포시 > 서귀포시내
# 694                 김서방재첩해장국       제주시 > 제주시내
# 695                     까떼커피        서귀포시 > 표선
# 696                     까망돼지     서귀포시 > 서귀포시내
# 697                      까미노         제주시 > 애월
# 698                   깜돈 흑돼지       제주시 > 제주시내
# 699                   꼬꼬닭한마리        서귀포시 > 안덕
# 700                  꼬신김밥 본점       제주시 > 제주시내
# 701                      꽃가람        서귀포시 > 성산
# 702               김명자굴국밥 화북점       제주시 > 제주시내
# 703                     꽃밭에서       제주시 > 제주시내
# 704                      꽃자리     서귀포시 > 서귀포시내
# 705                      꽃향유         제주시 > 애월
# 706                     나까무라       제주시 > 제주시내
# 707                     나눔김밥       제주시 > 제주시내
# 708                    나라돈까스       제주시 > 제주시내
# 709                    나목도식당        서귀포시 > 표선
# 710                     나무카페         제주시 > 조천
# 711                     나주닭집       제주시 > 제주시내
# 712                    난드르바당     서귀포시 > 서귀포시내
# 713                     낭만주의       제주시 > 제주시내
# 714                     낭쿰낭쿰     서귀포시 > 서귀포시내
# 715                내가 찾은 맛고을       제주시 > 제주시내
# 716                       내담        서귀포시 > 중문
# 717                   내창생태카페        서귀포시 > 남원
# 718                너는파라다이스길리         제주시 > 구좌
# 719                  너와의 첫여행         제주시 > 애월
# 720              넉둥베기 고사리육개장       제주시 > 제주시내
# 721                   넘버 138     서귀포시 > 서귀포시내
# 722                   네이쳐캔바스        서귀포시 > 남원
# 723                   노네임드봉개       제주시 > 제주시내
# 724                    노리터스낵         제주시 > 애월
# 725               노을과 어울림 카페        서귀포시 > 대정
# 726                      노조미       제주시 > 제주시내
# 727                      녹나무       제주시 > 제주시내
# 728                   녹원전통찻집       제주시 > 제주시내
# 729                     놀놀카페         제주시 > 구좌
# 730                    누룽지식당       제주시 > 제주시내
# 731                       누옥       제주시 > 제주시내
# 732                    뉴남원분식        서귀포시 > 남원
# 733                    뉴저지카페         제주시 > 한경
# 734                   느지리식식당         제주시 > 한림
# 735                      늘예솔        서귀포시 > 성산
# 736              늘푸른농원 연리지가든         제주시 > 한경
# 737                     노을코지       제주시 > 제주시내
# 738                  다가미 애월점         제주시 > 애월
# 739                      다니쉬         제주시 > 조천
# 740                다다익고 정육식당     서귀포시 > 서귀포시내
# 741                      다담은       제주시 > 제주시내
# 742                   다람쥐 식탁         제주시 > 한림
# 743                  다래향 세화점         제주시 > 구좌
# 744                   다래향2호점         제주시 > 구좌
# 745                      다미안     서귀포시 > 서귀포시내
# 746                      다미진        서귀포시 > 표선
# 747                      다미회       제주시 > 제주시내
# 748                   다올김밥분식       제주시 > 제주시내
# 749                니모메빈티지라운지       제주시 > 제주시내
# 750                     다정이네     서귀포시 > 서귀포시내
# 751                     다해복국       제주시 > 제주시내
# 752                     달래식당        서귀포시 > 성산
# 753                     달리다방         제주시 > 구좌
# 754                      달리맨        서귀포시 > 성산
# 755                    달리북카페         제주시 > 한림
# 756                  달빛머금은카페       제주시 > 제주시내
# 757                       달에         제주시 > 애월
# 758                     달인수산     서귀포시 > 서귀포시내
# 759                     달페이지     서귀포시 > 서귀포시내
# 760                       담다         제주시 > 한림
# 761              다이노바이트 샌드위치       제주시 > 제주시내
# 762                   대굴대굴구이       제주시 > 제주시내
# 763                      대기정     서귀포시 > 서귀포시내
# 764                대독장(제주본점)       제주시 > 제주시내
# 765                      대운정       제주시 > 제주시내
# 766                    대춘해장국       제주시 > 제주시내
# 767                대춘해장국 노형점       제주시 > 제주시내
# 768                대춘해장국 시청점       제주시 > 제주시내
# 769                     대포횟집        서귀포시 > 중문
# 770                   대향연탄구이     서귀포시 > 서귀포시내
# 771                     더 코브        서귀포시 > 안덕
# 772                    더 콘테나         제주시 > 조천
# 773                   당케올레국수        서귀포시 > 표선
# 774                     더로맨틱         제주시 > 조천
# 775                   더비치하우스        서귀포시 > 성산
# 776                 덕승식당(신관)  서귀포시 > region2>
# 777               덕인당보리빵 제주점       제주시 > 제주시내
# 778                       델리       제주시 > 제주시내
# 779                  델문도로스터스       제주시 > 제주시내
# 780                      도가촌     서귀포시 > 서귀포시내
# 781                도남오거리 도남점       제주시 > 제주시내
# 782                    도도톳김밥         제주시 > 구좌
# 783                       도렐        서귀포시 > 성산
# 784                     도리화과       제주시 > 제주시내
# 785                    더건강한빵        서귀포시 > 중문
# 786                       돈가       제주시 > 제주시내
# 787                   돈돼지흑돼지        서귀포시 > 표선
# 788                      돈사촌       제주시 > 제주시내
# 789                 돈이랑 서귀포점        서귀포시 > 중문
# 790                       돈채      섬 속의 섬 > 우도
# 791                    돈카츠서황         제주시 > 애월
# 792                   돈파스타정원         제주시 > 애월
# 793                      돈풍년       제주시 > 제주시내
# 794                       돌섬        서귀포시 > 성산
# 795               돌카롱 사려니숲길점         제주시 > 조천
# 796                  돌카롱 애월점         제주시 > 애월
# 797                     독도참치     서귀포시 > 서귀포시내
# 798                    돌코롬허니         제주시 > 구좌
# 799                 돌토고리족욕카페        서귀포시 > 표선
# 800                      돔베돈       제주시 > 제주시내
# 801                      동구미         제주시 > 조천
# 802            동그라미식육식당(돈델리)     서귀포시 > 서귀포시내
# 803                동글이흑돼지바베큐     서귀포시 > 서귀포시내
# 804                    동동차이나        서귀포시 > 남원
# 805                      동막골       제주시 > 제주시내
# 806                     동백별장       제주시 > 제주시내
# 807                      동북왕       제주시 > 제주시내
# 808                     동우통닭       제주시 > 제주시내
# 809                    돌코롬봉봉        서귀포시 > 표선
# 810                      동해루     섬 속의 섬 > 추차도
# 811                   돼지굽는정원         제주시 > 한림
# 812                    두가시가든        서귀포시 > 표선
# 813                     두루김밥       제주시 > 제주시내
# 814                     두루두루       제주시 > 제주시내
# 815                     두리호집         제주시 > 한림
# 816                 두툼한고기돈돼지         제주시 > 조천
# 817                      듀포레       제주시 > 제주시내
# 818                디 아일렛 라운지        서귀포시 > 안덕
# 819                       딕시     서귀포시 > 서귀포시내
# 820                   딤섬9898       제주시 > 제주시내
# 821                    동이트는집       제주시 > 제주시내
# 822                       뚜르        서귀포시 > 표선
# 823                    뚱보아저씨         제주시 > 한경
# 824                 뚱순이 꼬마김밥     서귀포시 > 서귀포시내
# 825                      뜰향기         제주시 > 조천
# 826                    라 아바나       제주시 > 제주시내
# 827                     라쁠라주       제주시 > 제주시내
# 828                   라스또르따스         제주시 > 애월
# 829               라온베이커리 남녕점       제주시 > 제주시내
# 830                   라운지 38       제주시 > 제주시내
# 831                라운지엑스 애월점         제주시 > 애월
# 832                     라토커피       제주시 > 제주시내
# 833                   라포레사려니         제주시 > 조천
# 834                   랜딩 라운지        서귀포시 > 안덕
# 835                     레이식당         제주시 > 구좌
# 836                    레이지펌프         제주시 > 애월
# 837                 로맨틱하드보일드         제주시 > 애월
# 838                      로빙화        서귀포시 > 남원
# 839                로스터리카페 담담         제주시 > 한경
# 840                   로스트&헤븐       제주시 > 제주시내
# 841               로치아 커피로스터스       제주시 > 제주시내
# 842                   룡천왕갈비탕       제주시 > 제주시내
# 843              루스트플레이스 구남점       제주시 > 제주시내
# 844             루스트플레이스 베라체점       제주시 > 제주시내
# 845             루스트플레이스 서귀포점     서귀포시 > 서귀포시내
# 846              루스트플레이스 시청점       제주시 > 제주시내
# 847              루스트플레이스 아라점       제주시 > 제주시내
# 848            루스트플레이스 아이파크점       제주시 > 제주시내
# 849              루스트플레이스 외도점       제주시 > 제주시내
# 850              루스트플레이스 제원점       제주시 > 제주시내
# 851             루스트플레이스 칠성로점       제주시 > 제주시내
# 852                   르에스까르고       제주시 > 제주시내
# 853                르토아 베이스먼트         제주시 > 구좌
# 854              리치망고 도두해안로점       제주시 > 제주시내
# 855               리치망고 신화월드점        서귀포시 > 안덕
# 856              루스트플레이스 삼화점       제주시 > 제주시내
# 857                     리틀비엣       제주시 > 제주시내
# 858                       마농       제주시 > 제주시내
# 859            마농오메기통닭마농문어통닭     서귀포시 > 서귀포시내
# 860                     마님순대       제주시 > 제주시내
# 861                       마돈        서귀포시 > 성산
# 862                  마라도별장식당     섬 속의 섬 > 마라도
# 863                    마라도횟집       제주시 > 제주시내
# 864                    마라톤식당       제주시 > 제주시내
# 865                     마레벤또         제주시 > 애월
# 866                   마마무말가든       제주시 > 제주시내
# 867                     마마식당     섬 속의 섬 > 추차도
# 868                 리치망고 협재점         제주시 > 한림
# 869                      마실디     서귀포시 > 서귀포시내
# 870                     마음카페        서귀포시 > 표선
# 871                   마중물삼계탕       제주시 > 제주시내
# 872                      마틸다         제주시 > 애월
# 873                 만강촌옛날칼국수       제주시 > 제주시내
# 874                     만덕식당         제주시 > 한경
# 875                      만배성       제주시 > 제주시내
# 876                    만복흑돼지        서귀포시 > 안덕
# 877                      만부정       제주시 > 제주시내
# 878                     만선바다       제주시 > 제주시내
# 879                  만세국수 본점       제주시 > 제주시내
# 880                      마모루       제주시 > 제주시내
# 881                   만조이천쌀밥        서귀포시 > 성산
# 882                      맛나리     서귀포시 > 서귀포시내
# 883                 맛있는 여가생활         제주시 > 한림
# 884                     맛있는집     서귀포시 > 서귀포시내
# 885                 망고홀릭 법환점     서귀포시 > 서귀포시내
# 886              망고홀릭 성산일출봉점        서귀포시 > 성산
# 887                   매기의 추억         제주시 > 애월
# 888                     매일통닭     서귀포시 > 서귀포시내
# 889                 맥파이 브루어리       제주시 > 제주시내
# 890                 맥파이 블루버드       제주시 > 제주시내
# 891                   맨도롱해장국     서귀포시 > 서귀포시내
# 892                      만월당         제주시 > 구좌
# 893                먹쿠슬낭여행자카페       제주시 > 제주시내
# 894                     메로식당     서귀포시 > 서귀포시내
# 895                    메종드베니       제주시 > 제주시내
# 896                  메종드쁘티푸르       제주시 > 제주시내
# 897              메종드쁘티푸르 노형점       제주시 > 제주시내
# 898                 멘도롱 cafe        서귀포시 > 대정
# 899                     면사무소         제주시 > 애월
# 900                   명도암수다뜰       제주시 > 제주시내
# 901                  명문사거리식당        서귀포시 > 표선
# 902                       명물       제주시 > 제주시내
# 903                     명성식당       제주시 > 제주시내
# 904                     머문카페         제주시 > 구좌
# 905               명품전통육개장 본점       제주시 > 제주시내
# 906                    모노클제주        서귀포시 > 남원
# 907                     모뉴에트         제주시 > 구좌
# 908                     모닥치기       제주시 > 제주시내
# 909                    모리노코에       제주시 > 제주시내
# 910                      모메존       제주시 > 제주시내
# 911                       모앙       제주시 > 제주시내
# 912               모이세해장국 노형점       제주시 > 제주시내
# 913                    모퉁이스낵        서귀포시 > 성산
# 914                    몬스터살롱       제주시 > 제주시내
# 915                 몬스테라 자구리     서귀포시 > 서귀포시내
# 916                     명태명가       제주시 > 제주시내
# 917                      몽생이         제주시 > 한경
# 918      몽키비치클럽 Monkey Beach        서귀포시 > 중문
# 919                묘한상점 묘한카페        서귀포시 > 성산
# 920                     무거버거         제주시 > 조천
# 921                무뚱 식도락 식당        서귀포시 > 남원
# 922                     무상찻집       제주시 > 제주시내
# 923                    무진장식당       제주시 > 제주시내
# 924                      문게야       제주시 > 제주시내
# 925                       문쏘         제주시 > 한림
# 926        문어빵굽는 문빵9 서귀포올레시장     서귀포시 > 서귀포시내
# 927                   문치비 본점     서귀포시 > 서귀포시내
# 928                  못잊어 감자탕       제주시 > 제주시내
# 929                  미드나잇 제주        서귀포시 > 안덕
# 930                   미래뷔페정식     서귀포시 > 서귀포시내
# 931                      미루네       제주시 > 제주시내
# 932                     미미국수       제주시 > 제주시내
# 933                 미번베트남쌀국수         제주시 > 한림
# 934                    미복빈대떡       제주시 > 제주시내
# 935                미소짓는 흑도야지       제주시 > 제주시내
# 936                    미스틱3도       제주시 > 제주시내
# 937                       미원       제주시 > 제주시내
# 938                   미인계 카페         제주시 > 애월
# 939                      미쿠니       제주시 > 제주시내
# 940                 미나리(제주시)       제주시 > 제주시내
# 941                  민봉태중화요리       제주시 > 제주시내
# 942                      밀리우        서귀포시 > 표선
# 943                     바그다드       제주시 > 제주시내
# 944                       바농     서귀포시 > 서귀포시내
# 945                   바닐라파레트       제주시 > 제주시내
# 946                    바다가는길     서귀포시 > 서귀포시내
# 947           바다를 본 돼지(서귀포점)     서귀포시 > 서귀포시내
# 948                     바다어멍     서귀포시 > 서귀포시내
# 949                     바다잔치       제주시 > 제주시내
# 950                     바다제비         제주시 > 한림
# 951                 바라나시 책골목       제주시 > 제주시내
# 952               바람이풀에그림그린날        서귀포시 > 안덕
# 953                     바람카페       제주시 > 제주시내
# 954                  바램목장&카페        서귀포시 > 안덕
# 955                바로족발보쌈 별관       제주시 > 제주시내
# 956                바로족발보쌈 본점       제주시 > 제주시내
# 957                     바보라면         제주시 > 구좌
# 958              바삭돈까스 신서귀포점     서귀포시 > 서귀포시내
# 959                      바온탑        서귀포시 > 안덕
# 960              바우네나주곰탕 삼화점       제주시 > 제주시내
# 961                    바움하우스       제주시 > 제주시내
# 962                     바위소리      섬 속의 섬 > 우도
# 963                  바캉스샤브샤브         제주시 > 조천
# 964                    반딧불한담         제주시 > 애월
# 965                     밤낮가온       제주시 > 제주시내
# 966                     방긋스낵         제주시 > 구좌
# 967                       방듸        서귀포시 > 성산
# 968                      방모루         제주시 > 조천
# 969                      배롱개         제주시 > 구좌
# 970                  백기해녀의 집        서귀포시 > 성산
# 971                      백리향         제주시 > 조천
# 972                     백번가든         제주시 > 애월
# 973                     뱅인타코        서귀포시 > 대정
# 974                    버거307         제주시 > 조천
# 975                      박장군        서귀포시 > 안덕
# 976                     번개피자        서귀포시 > 안덕
# 977                  법환어촌계횟집     서귀포시 > 서귀포시내
# ...
# 1334  상세정보\n확장됨\n\n도심 속의 넓은 정원을 보유한 브런치카페\n\n제주공항 인근...
# 1335  상세정보\n확장됨\n\n핸드드립 전문 1인 카페\n\n애월항 인근에 위치한 핸드드립...
# 1336  상세정보\n확장됨\n\n제리스펍은 수제맥주와 음식, 수입맥주를 제공한다.\n\n매장...
# 1337  상세정보\n확장됨\n\n추자도 제일식당은 추자도 추자항 근처에 위치한 횟집으로 삼치...
# 1338  상세정보\n확장됨\n\n제주 드림타워 복합리조트 내 그랜드 하얏트 제주 3층에 위치...
# 1339  상세정보\n확장됨\n\n먹는 입과 보는 눈이 즐거워지는 분식집\n\n제주의 대표 관...
# 1340  상세정보\n확장됨\n\n제주마늘광어를 직접 양식하여 믿고 먹을 수 있는 곳으로 알려...
# 1341  상세정보\n확장됨\n\n애월해안도로에 위치한 갈치, 고등어조림 맛집\n 애월해안도로...
# 1342  상세정보\n확장됨\n\n제주에 전혀 새로운 그야말로 HOT한 CAFÉ가 등장했다!\...
# 1343  상세정보\n확장됨\n\n제주공항 인근에 위치한 가성비 좋은 정식뷔페\n\n제주공항 ...
# 1344  상세정보\n확장됨\n\n가시없는 갈치조림 전문점\n\n제주에서 손꼽히는 해수욕장인 ...
# 1345  상세정보\n확장됨\n\n바지락회무침, 두부바지락전골, 바지락 칼국수 등 전라도 음식...
# 1346  상세정보\n확장됨\n넓은 주차장과, 아이들이 있는 부모님들이 편하게 식사할 수 있도...
# 1347  상세정보\n확장됨\n\n제주돌창고, 제주도에 오직 하나뿐인 방앗간 카페\n\n제주돌...
# 1348  상세정보\n확장됨\n\n제주돔베막국수는 2016년 호텔신라의 레시피 전수와 리모델링...
# 1349  상세정보\n확장됨\n\n갈치, 고등어, 흑돼지를 한자리에서 즐길 수 있는 제주맛촌\...
# 1350  상세정보\n확장됨\n\n깻잎에 쌈을 싸먹는 전복김밥\n\n제주시 협재리에 위치한 김...
# 1351  상세정보\n확장됨\n\n통갈치구이를 메인으로 톳밥, 문어숙회, 생선조림, 수육, 잡...
# 1352  상세정보\n확장됨\n\n\n제주복돈은 제주시 노형동에 위치하였으며\n제주에서 복분자...
# 1353  상세정보\n확장됨\n제제본초협동조합\n\n제주본초협동조합은 제주에서 자생하는 약물들...
# 1354  상세정보\n확장됨\n\n\n\n\n제주산 식자재를 사용하여 안전하고 건강한 먹거리를...
# 1355  상세정보\n확장됨\n제주샘주 영농협동조합\n\n제주도 서쪽에는 제주를 대표하는 오메...
# 1356  상세정보\n확장됨\n\n기정떡은 막걸리로 발효하여 쪄낸 전통떡인 증편의 다른 이름이...
# 1357  상세정보\n확장됨\n\n제주의 겨울을 담은 제주 눈꽃빙수 맛집\n\n제주의 겨울을 ...
# 1358                                          상세정보\n확장됨
# 1359  상세정보\n확장됨\n\n제주스에서만 맛볼 수 있는 특별한 수제주스\n\n제주 동문재...
# 1360  상세정보\n확장됨\n\n새우를 주제로 한 다양하고 간단한 요리\n\n구제주 제주북초...
# 1361  상세정보\n확장됨\n\n제주신화월드에는 한식, 중식, 일식, 다양한 스타일의 요리는...
# 1362  상세정보\n확장됨\n\n제주신화월드 내 위치한 경양식 맛집\n\n제주신화월드 내 푸...
# 1363  상세정보\n확장됨\n\n서귀포에 위치한 제주 로컬수제맥주 전문점\n\n서귀포에 위치...
# 1364  상세정보\n확장됨\n\n서귀포 올레시장 인근에 위치한 수제맥주 전문점\n\n서귀포 ...
# 1365  상세정보\n확장됨\n\n제주산 보말로 만들어낸 다양한 요리들\n\n용연야범으로 유명...
# 1366  상세정보\n확장됨\n\n제주신화월드 내 맛있는 중국음식점\n\n제주신화월드 내 지하...
# 1367  상세정보\n확장됨\n제주와이너리\n\n제주의 새콤달콤 감귤을 술로 만나보자. 제주시...
# 1368  상세정보\n확장됨\n\n제주선 더블랙에서는 1℃ 저온에서 192시간 동안 습식 숙성...
# 1369  상세정보\n확장됨\n한림항 바로 앞에 위치한 제주 보말요리 전문점.\n대표 메뉴로는...
# 1370  상세정보\n확장됨\n\n옛부터 찹쌀로 만들어지는 인절미는 맵쌀로 만들어지는 떡에 비...
# 1371  상세정보\n확장됨\n\n낙지 한마리 해물짬뽕과 불향의 깊고 진한 우육짬뽕\n\n제주...
# 1372  상세정보\n확장됨\n\n겨울철에 먹기 좋은 매생이와 전복으로 꽉 찬 영양만점 한식을...
# 1373  상세정보\n확장됨\n\n아라동에 위치한 소고기구이 전문점\n\n아라동에 위치한 제주...
# 1374  상세정보\n확장됨\n오랫동안 운영해왔던 <제주침시술소>라는 간판을 그대로 사용하고 ...
# 1375  상세정보\n확장됨\n\n제주콩순옥은 2016년 호텔신라의 레시피 전수와 리모델링 지...
# 1376  상세정보\n확장됨\n\n아름다운 석양과 함께 할 수 있는 제주크랩잭\n\n애월에 위...
# 1377  상세정보\n확장됨\n\n풍천장어구이 및 꼼장어 전문점\n\n구제주 고마로길 초입에서...
# 1378  상세정보\n확장됨\n\n소스를 부어먹는 흑돼지 수제버거전문점\n\n서귀포시 토산리에...
# 1379  상세정보\n확장됨\n\n사회적기업 파란공장이 제주술생산자협동조합과 함께 만든 '제주...
# 1380  상세정보\n확장됨\n\n다양한 재료를 사용한 다양한 주제의 라면집\n\n애월해안도로...
# 1381  상세정보\n확장됨\n조가네갑오징어 신제주점은 프렌차이즈 식당임에도 불구하고, 제주도...
# 1382  상세정보\n확장됨\n\n\n멘트에 따라 커피 가격이 달라지는 재미있는 카페, 조아찌...
# 1383  상세정보\n확장됨\n\n건강과 정성을 생각한 쌀 빵 전문 베이커리\n\n아라동에 위...
# 1384  상세정보\n확장됨\n\n뜨끈하고 시원한 국물의 해물뚝배기가 맛있는 집이다.\n아침식...
# 1385  상세정보\n확장됨\n종달리 골목의 식육점 건물 간판을 그대로 사용하며 운영 중인 일...
# 1386  상세정보\n확장됨\n\n예로부터 전복은 진상품으로 바쳐질 만큼 귀하고 좋은 식재료로...
# 1387  상세정보\n확장됨\n\n종이비행기는 2층 공간이 마련되어 있어 편안한 제주 바다 전...
# 1388  상세정보\n확장됨\n\n바닷가 쪽에 앉은 4층 의 흰색과 파아란 색으로 작은 성 모...
# 1389  상세정보\n확장됨\n\n구수한 솥밥이 생각날 땐 죽성고을\n\n오등동에 위치한 죽성...
# 1390  상세정보\n확장됨\n\n준반점은 함덕 서우봉 해변가에 위치한 중화요리점으로 신선한 ...
# 1391  상세정보\n확장됨\n\n계절마다 재료가 바뀌는 제철짬뽕\n\n제주시 신창리에 위치한...
# 1392  상세정보\n확장됨\n제주 특산물로 만든 한치빵을 판매하는 곳.\n하고수동해수욕장에 ...
# 1393  상세정보\n확장됨\n흑돼지, 제주은갈치, 오분작 뚝배기 등을 주메뉴로 하고 있습니다...
# 1394  상세정보\n확장됨\n\n중문관광단지에 위치한 말고기, 흑돼지, 갈치, 전복죽 등을 ...
# 1395  상세정보\n확장됨\n\n집밥이 먹고 싶을때 생각나는 정식전문점\n\n서귀포시 중문에...
# 1396  상세정보\n확장됨\n\n제주의 신선한 재료를 사용하여 만든 해물라면\n\n서귀포시 ...
# 1397  상세정보\n확장됨\n\n서귀포에 위치한 중화요리 전문점 사해방.\n손님들의 입맛에 ...
# 1398  상세정보\n확장됨\n공항에서 차로 10분 거리인 용담 레포츠 공원 근처에 있다.\n...
# 1399  상세정보\n확장됨\n\n우도에서 맛 보는 원조우도땅콩아이스크림\n\n우도 검멀레 해...
# 1400  상세정보\n확장됨\n제주에서 즐기는 진정한 힐링\n\n한라산과 푸른 제주바다가 한눈...
# 1401  상세정보\n확장됨\n\n'아라'라는 말은 순우리말로 '바다' 라는 뜻을 갖고 있으며...
# 1402  상세정보\n확장됨\n신선한 재료에 직접 개발한 양념을 넣어 끓인 순두부의 칼칼하고 ...
# 1403  상세정보\n확장됨\n\n두툼한 고기에 뼈대가 붙어 있는 돈마호크\n\n제주시 한라수...
# 1404  상세정보\n확장됨\n\n중문랜드 2층에 위치하고 제주 향토음식도 제공하는 뷔페 음식...
# 1405  상세정보\n확장됨\n\n바다를 요리하는 횟집\n\n제주올레 10코스 인근에 위치한 ...
# 1406  상세정보\n확장됨\n공항 근처인 연동에 위치했다. 황태해장국, 황태구이와 더불어 게...
# 1407  상세정보\n확장됨\n\n이른 아침식사가 가능한 해장국 맛집\n\n삼화지구에 위치한 ...
# 1408  상세정보\n확장됨\n\n다양한 향토음식을 맛 볼수 있는 곳\n\n서귀포 시내의 명물...
# 1409  상세정보\n확장됨\n\n구좌읍 세화리 마을주민 477명이 모여 만든 세화마을협동조합...
# 1410  상세정보\n확장됨\n\n한 때 유명한 멘트였던 "짜장면 시키신 분~!"\nMBC 무...
# 1411  상세정보\n확장됨\n\n해안도로 위 바다의 향이 물씬 나는 음식들을 맛보다\n\n제...
# 1412  상세정보\n확장됨\n\n\n한경면 용수리 해안도로에 위치한 카페로 풍차로 유명한 신...
# 1413  상세정보\n확장됨\n\n차귀도놀빛바다는 92석의 좌석수로 넉넉하게 편안한 자리를 이...
# 1414  상세정보\n확장됨\n\n최고의 쉐프가 만들어 내는 WELL-BEING식당\n\n여유...
# 1415  상세정보\n확장됨\n차마실\n\n제주시 애월읍에 있는 전통찻집 차마실은 직접 만든 ...
# 1416  상세정보\n확장됨\n\n진미네식당은 2014년 호텔신라의 레시피 전수와 리모델링 지...
# 1417  상세정보\n확장됨\n\n차이나마씸은 2017년 호텔신라의 레시피 전수와 리모델링 지...
# 1418  상세정보\n확장됨\n\n제주에서 푸짐한 한정식을 즐길수 있는 곳\n\n제주시 오라동...
# 1419  상세정보\n확장됨\n\n365일 즐기는 열무국수와 멸추김밥이 있는 곳\n\n제주 한...
# 1420  상세정보\n확장됨\n\n제철나물 산채비빕밥을 맛볼 수 있는 곳\n\n제주시내를 벗어...
# 1421  상세정보\n확장됨\n\n축협에서 납품 되고 있는 최상급 돼지고기만을 취급한다.\n대...
# 1422  상세정보\n확장됨\n\n서귀포항 입구에 위치하고 오전에 문을 여는 가게로\n7,00...
# 1423  상세정보\n확장됨\n함덕해수욕장 근처 제주 가정식 전문점으로, 제주도의 전통 집을 ...
# 1424  상세정보\n확장됨\n\n눈 덮인 한라산의 모습을 한 팡도르를 맛볼 수 있는 곳\n\...
# 1425  상세정보\n확장됨\n\n제주 신창에서 아침식사 가능한 해장국전문점\n\n제주시 한경...
# 1426  상세정보\n확장됨\n\n\n\n관광객이 너무 많아져서 언제나 붐비는 월정리에 조용한...
# 1427  상세정보\n확장됨\n\n삼도이동에 위치한 해물짬뽕이 맛있는 집 \n\n삼도이동에 위...
# 1428  상세정보\n확장됨\n\n천보식당은 2015년 호텔신라의 레시피 전수와 리모델링 지원...
# 1429  상세정보\n확장됨\n\n제주산 생 근고기 구이 전문점\n\n중문관광단지 입구에 위치...
# 1430  상세정보\n확장됨\n\n제주산 흑돼지 근고기 구이 전문점\n\n서귀포시 표선해수욕장...
# 1431  상세정보\n확장됨\n\n제주 드림타워 복합리조트 내 그랜드 하얏트 제주 8층에 위치...
# 1432  상세정보\n확장됨\n\n계절꽃의 향기를 만끽할 수 있는 곳\n\n송당리에 위치한 카...
# 1433  상세정보\n확장됨\n\n구좌 당근으로 직접 만든 음료와 디저트가 있는 곳\n\n세화...
# 1434  상세정보\n확장됨\n\n우리들의 놀이공간—엔터테인먼트 & 스포츠펍, 카페 베트로\n...
# 1435                                          상세정보\n확장됨
# 1436  상세정보\n확장됨\n\n곽지과물해변에 위치한 디저트카페 소바니는\n시리얼 아이스크림...
# 1437  상세정보\n확장됨\n통유리로 보이는 전경이 근사한 감성카페. \n건물 내, 외부 자...
# 1438  상세정보\n확장됨\n\n함덕서우봉해수욕장에서 멀지 않은 카페 3535.1은 정원이 ...
# 1439  상세정보\n확장됨\n사려니숲길 근처 사진 찍기 좋은 카페.\n카페 앞에는 작은 숲이...
# 1440  상세정보\n확장됨\n\n제주산 흑돼지구이 근고기 전문점\n\n용담2동에 위치한 제주...
# 1441  상세정보\n확장됨\n\n성산일출봉과 우도가 한눈에 보이는 오션뷰카페\n\n서귀포시 ...
# 1442  상세정보\n확장됨\n\n카페더몹시는 제주시 외도동 바닷가에 있는 갤러리카페이다.\n...
# 1443  상세정보\n확장됨\n\n에그타르트가 맛있는 초록초록한 감성 카페\n\n하도리에 위치...
# 1444  상세정보\n확장됨\n\n카페루나는 산방산이 내려다보이는 언덕에 위치해 있으며 드립커...
# 1445  상세정보\n확장됨\n\n카페 비글은 이름 그대로 비글 강아지가 살고 있는 애견 동반...
# 1446  상세정보\n확장됨\n천년의 숲 비자림 삼거리에 위치한 70평 규모의 카페비몽입니다....
# 1447  상세정보\n확장됨\n\n제주시청 인근에 위치한 건강한 빵집\n 제주시청 인근에 위치...
# 1448  상세정보\n확장됨\n카페 선흘은 조천읍의 감성 카페로 펜션도 함께 운영하고 있다. ...
# 1449  상세정보\n확장됨\n\n중문관광단지 중심에 위치한 카페세렌디는 접근성, 이동성, 편...
# 1450  상세정보\n확장됨\n스노우빈\n\n제주에는 한여름에도 크리스마스 분위기를 느낄 수 ...
# 1451  상세정보\n확장됨\n\n건축문화대상에서 상을 받은 오션뷰 카페\n\n제주시 신산리에...
# 1452  상세정보\n확장됨\n\n무지개해안도로에 위치한 오션뷰 베이커리 카페\n\n공항뒷편의...
# 1453  상세정보\n확장됨\n\n성이시돌 목장의 유기농 우유로 만든 음료\n\n성이시돌 목장...
# 1454  상세정보\n확장됨\n\n우도땅콩아이스크림과 땅콩와플\n\n섬 속의 섬 우도에 위치한...
# 1455  상세정보\n확장됨\n\n800여평의 귤밭에 위치한 브런치카페\n\n최근 제주의 핫플...
# 1456  상세정보\n확장됨\n애월항 앞에 위치한 카페.\n카페 이름은 애월 하물(용천수)이 ...
# 1457  상세정보\n확장됨\n\n오래된 TV 속에 나를 담을 수 있는 곳\n\n세화 해수욕장...
# 1458  상세정보\n확장됨\n하추자도에 위치한 카페로서\n추자바다 바라보며 쉴 수 있는 무인...
# 1459  상세정보\n확장됨\n\n커먼브릭은 순수 쇠고기 패티 버거와 탑 오브 엘설런스를 수상...
# 1460  상세정보\n확장됨\n\n여유를 느낄 수 있는 커피가게&쉬고가게\n\n표선해수욕장 인...
# 1461  상세정보\n확장됨\n\n치즈빙수로 유명한 제주시에 위치한 카페다.\n내부에 진열되어...
# 1462  상세정보\n확장됨\n\n커피림은 한라수목원 입구에 위치하고 있어 나무와 숲에 둘러싸...
# 1463  상세정보\n확장됨\n커피먹는 고냉이\n\n소박함과 정겨움이 가득한 인테리어의 커피먹...
# 1464  상세정보\n확장됨\n\n돌담으로 지어진 레트로한 디저트카페\n\n제주시 한림에 위치...
# 1465  상세정보\n확장됨\n\n추자도에서 유일하게 커피와 빵을 즐길 수 있는 곳으로, 매일...
# 1466  상세정보\n확장됨\n\n남광초등학교 근처에 위치한 커피주의보는 초록초록한 식물과 흰...
# 1467  상세정보\n확장됨\n\n진하고 맛있는 자신만의 커피를 찾으러 가보자.\n\n대한민국...
# 1468  상세정보\n확장됨\n\n제주 중선농원에 위치한 복합문화공간\n\n제주 중선농원에 위...
# 1469  상세정보\n확장됨\n\n커피파인더는 제주시청 근처 골목길 안쪽에 위치해있다.\n카페...
# 1470  상세정보\n확장됨\n\n감성적인 분위기의 레스토랑 컬쳐드\n\n제주시 아라동에 위치...
# 1471  상세정보\n확장됨\n\n제주 시내에서 특색 있는 음료를 찾는다면 컴플리트 커피에서 ...
# 1472  상세정보\n확장됨\n\n컴홈카페는 집에서 즐기는 브런치와 디저트라는 테마로 모든메뉴...
# 1473  상세정보\n확장됨\n제주공항과 가깝고 볼거리가 다양해, 많은 사람이 모이는 동문시장...
# 1474  상세정보\n확장됨\n\n건강한 재료가 들어간 비법소스와 조화를 이루는 바삭한 안심돈...
# 1475  상세정보\n확장됨\n\n표선 해수욕장에 위치한 카페 코코티에\n\n표선 해수욕장에 ...
# 1476  상세정보\n확장됨\n\n용머리해안 인근에 위치한 오션뷰 카페\n\n용머리해안 인근에...
# 1477  상세정보\n확장됨\n이름 속 '쿠싱'은 '구수하다'라는 의미의 제주어다. 그날 새로...
# 1478  상세정보\n확장됨\n애월 해안도로에 위치한 고내포구 인근 일본식 샤브샤브(나베)전문...
# 1479  상세정보\n확장됨\n\n애월해안도로에 위치한 누워서 바다 보는 카페\n\n애월해안도...
# 1480  상세정보\n확장됨\n\n시골마을의 놀러온 듯한 정서의 카페\n\n제주시 한경면에 위...
# 1481  상세정보\n확장됨\n\n형제섬이 보이는 제주흑돼지근고기 전문점\n\n대정읍 형제해안...
# 1482  상세정보\n확장됨\n\n신선한 제주 흑돼지를 즐길 수 있는 근고기전문점\n\n서귀포...
# 1483  상세정보\n확장됨\n\n서귀포 성산읍에 위치한 밀크티 전문점\n\n서귀포 성산읍에 ...
# 1484  상세정보\n확장됨\n\n\n\n'그듸'는 제주방언으로 '거기'라는 뜻이다. 키친그듸...
# 1485  상세정보\n확장됨\n\n킨포크에서는 천연발효 빵위에 다양한 토핑을 올린 브루스케타와...
# 1486  상세정보\n확장됨\n\n조천에 위치한 태국 요리 전문점 타무라. \n태국에서 요리를...
# 1487  상세정보\n확장됨\n\n푸짐한 해물이 들어있는 해물 뚝배기와 생선구이를 맛볼 수 있...
# 1488  상세정보\n확장됨\n\n시내에 인접한 숲 속 베이커리카페\n\n제주시 연북로 인근에...
# 1489  상세정보\n확장됨\n제주의 자연으로부터 나온 로컬 재료를 이용한 홈메이드 뷔페 자연...
# 1490  상세정보\n확장됨\n\n다양한 맛의 화덕피자를 즐기는 깔끔한 피자집\n\n탐라화덕피...
# 1491  상세정보\n확장됨\n\n제주흑돼지와 동치미 육수를 사용한 국수를 즐길 수 있는 탐라...
# 1492  상세정보\n확장됨\n\n두가지 해장국 메뉴와 두가지 돈가스 메뉴가 있는 곳\n\n제...
# 1493  상세정보\n확장됨\n\n동문시장 인근에 위치한 로컬 해장국 전문점\n\n제주 동문시...
# 1494  상세정보\n확장됨\n\n제주시 도심에서 1100도로를 따라 올라가는 길에 미국 남부...
# 1495  상세정보\n확장됨\n\n탭하우스더코너는 더핸드앤몰트브루어리, 맥파이브루어리, 제주지...
# 1496  상세정보\n확장됨\n다양한 일본식 덮밥, 정갈한 일본 가정식을 즐길 수 있는 곳.\...
# 1497  상세정보\n확장됨\n\n털보네 장원랜드는 장어와 일식 전문 '제주 일식'과 로스구이...
# 1498  상세정보\n확장됨\n\nTEXIA(텍시아) Cafe는 제주도 출신 아내와 미국인 남...
# 1499  상세정보\n확장됨\n항암효과가 뛰어난 상황버섯, 엄나무, 가시오가피, 황귀 등 각종...
# 1500  상세정보\n확장됨\n\n잘 숙성시킨 돼지고기와 직접 기른 싱싱한 야채 등 양질의 음...
# 1501  상세정보\n확장됨\n\n조미료를 쓰지 않아 담백한 맛을 자랑하는 토담골이다.\n토종...
# 1502  상세정보\n확장됨\n제주 시내에 위치한 ‘토이다방’은 장난감을 좋아하는 어른들을 위...
# 1503  상세정보\n확장됨\n토향\n\n탁 트인 바다와 아름다운 섬 차귀도가 어우러진 풍경을...
# 1504  상세정보\n확장됨\n\n바베큐식으로 구워 담백한 돼지고기구이\n\n제주시 외도동에 ...
# 1505  상세정보\n확장됨\n\n다양한 해산물을 이용한 칼국수와 뚝배기가 있는 곳\n\n섬 ...
# 1506  상세정보\n확장됨\n\n3단 트레이 브런치가 유명한 금능해변 맛집\n\n금능 해수욕...
# 1507  상세정보\n확장됨\n\n파리바게뜨는 프랑스 전통의 베이커리 프랜차이즈 시스템을 운영...
# 1508  상세정보\n확장됨\n파리바게트는 프랑스 전통의 베이커리 프랜차이즈 시스템을 운영하고...
# 1509  상세정보\n확장됨\n\n프랑스 전통의 베이커리 프랜차이즈 시스템을 운영하고 있는 제...
# 1510  상세정보\n확장됨\n\n프랑스 전통의 베이커리 프랜차이즈 시스템을 운영하고 있는 제...
# 1511  상세정보\n확장됨\n\n파스꾸찌는 이탈리아 전통 에스프레소를 한국 문화와 접목시켜 ...
# 1512  상세정보\n확장됨\n\n월정리 해변이 한눈에 들어오는 카페\n\n월정리 해변이 한눈...
# 1513  상세정보\n확장됨\n\n서부두명품횟집거리에 들어서면 가장 초입에서 팔도수산을 찾을 ...
# 1514  상세정보\n확장됨\n제주에서 친환경공법으로 오랫동안 채소를 키워온 주인장이 운영하는...
# 1515  상세정보\n확장됨\n\n제주 드림타워 복합리조트 내 그랜드 하얏트 제주 3층에 위치...
# 1516  상세정보\n확장됨\n\n만두 찌는 열기와 냄새가 가득한 곳\n\n제주시 연동에 위치...
# 1517  상세정보\n확장됨\n\n레트로한 인테리어에 별빛이 내리는 카페\n\n천지연폭포 앞에...
# 1518  상세정보\n확장됨\n\n바쁜 일상 속에서 옛것을 찾아가는 편안한 카페\n\n제주시 ...
# 1519  상세정보\n확장됨\n\n제주 드림타워 복합리조트 내 그랜드 하얏트 제주 38층에 위...
# 1520  상세정보\n확장됨\n포토그릴 스테이크하우스는 아늑한 조명과 분위기 있는 음악, 창밖...
# 1521  상세정보\n확장됨\n\n보약 같은 진국, 푸주옥 설렁탕 \n\n푸주옥은 전국 곳곳에...
# 1522  상세정보\n확장됨\n\n일반 가정집을 개조한 정겹고 따스한 느낌의 감성 카페\n\n...
# 1523  상세정보\n확장됨\n\n옛 주택을 개조해서 만든 디저트카페\n\n제주시 송당리에 위...
# 1524  상세정보\n확장됨\n\n\n구좌읍 당근밭이 펼쳐지는 한적한 동네에 자리한 브런치 카...
# 1525  상세정보\n확장됨\n\n가정집을 개조하여 만든 빈티지한 카페&펍\n\n제주시 연동에...
# 1526  상세정보\n확장됨\n카페 주인이 직접 운영하는 추자도 카페이다.\n견과류의 고소함과...
# 1527  상세정보\n확장됨\n\n엔틱한 내부 장식과 자연을 벗삼은 아기자기한 정원풍경이 어우...
# 1528  상세정보\n확장됨\n\n성산읍과 표선면 중간쯤 온평포구 바로 앞에 위치한 "피자 아...
# 1529  상세정보\n확장됨\n\n버거 본연의 맛을 그대로 전달하는 버거 전문점\n\n이제는 ...
# 1530  상세정보\n확장됨\n\n사골, 아강발, 멸치, 고추씨 등을 영업시간 내내 끓여 만든...
# 1531  상세정보\n확장됨\n4대째 운영중인 경주 함양집의 제주 1호점이다.\n함덕해수욕장 ...
# 1532  상세정보\n확장됨\n\n하늘창고는 임실치즈가득 화덕피자와 맛있는 커피를 즐길 수 있...
# 1533  상세정보\n확장됨\n\n제주산 닭과 오리만을 사용하고, 인공 조미료 대신 천일염을,...
# 1534  상세정보\n확장됨\n남원읍 위미리에 위치한 이탈리안 요리 전문점.\n펜션을 함께 운...
# 1535  상세정보\n확장됨\n\n색다른 짬뽕을 만나볼 수 있는 중식점\n\n제주시 하귀리에 ...
# 1536                                          상세정보\n확장됨
# 1537  상세정보\n확장됨\n\n연동에서 운영했던 마카롱 테이크아웃 전문점 ‘하비마카롱’이\...
# 1538  상세정보\n확장됨\n\n\n하빌리스는 봄이면 왕벚꽃이 만개하는 제주시 전농로에 자리...
# 1539  상세정보\n확장됨\n\n30년 노하우로 깊은 맛과 풍미를 자아내는 하우스142\n\...
# 1540  상세정보\n확장됨\n약천사 인근에 위치한 흑돼지구이 전문점.\n전 좌석에서 제주 바...
# 1541  상세정보\n확장됨\n쇠소깍 가는 길에 들를만한 제주 가정식 식당이다. 11월이면 귤...
# 1542  상세정보\n확장됨\n봄이면 벚꽃길이 아름다운 하효동에 위치한 소머리 국밥과 소머리 ...
# 1543  상세정보\n확장됨\n\n제주공항 인근에 위치한 수제팥빵전문점\n\n신시가지의 제주한...
# 1544  상세정보\n확장됨\n\n서귀포 일호광장 근처에 위치한 부부가 운영하는 작은 김밥집이...
# 1545  상세정보\n확장됨\n\n한라산은 제주시에서 516도를 타고 서귀포로 넘어오다가 돈내...
# 1546  상세정보\n확장됨\n\n한림에 위치한 정육식당\n\n제주도 서부권 한림에 위치한 한...
# 1547  상세정보\n확장됨\n\n한돈과 한우를 참숯불에 즐길 수 있는 정육식당\n\n제주공항...
# 1548  상세정보\n확장됨\n\n한량 2010에서 맛보는 백목화, 런던포그 그리고 썸머라테\...
# 1549  상세정보\n확장됨\n\n제주 보말로 만든 깊은 맛의 보말칼국수\n\n제주시 한림에 ...
# 1550  상세정보\n확장됨\n추자도에서 녹두삼계탕을 먹을 수 있는 곳이다.\n내부도 깔끔하게...
# 1551  상세정보\n확장됨\n\n콩고물, 팥고물, 견과류의 세가지 오메기떡이 있는 곳\n\n...
# 1552  상세정보\n확장됨\n\n제주도 배경을 바라보며 먹는 한정식\n맛있는 한상가득 상차림...
# 1553  상세정보\n확장됨\n\n김치찌개와 김치찜을 맛볼 수 있는 곳\n\n걸매생태공원 북쪽...
# 1554  상세정보\n확장됨\n\n메인 메뉴인 추어탕은 물론 청국장 또한 집에서 직접 발효시킨...
# 1555  상세정보\n확장됨\n\n서귀포 올레시장 내 위치한 오메기떡 맛집\n\n서귀포 올레시...
# 1556  상세정보\n확장됨\n\n생선구이, 생선조림과 오션뷰 전문점\n\n함덕 해수욕장 인근...
# 1557  상세정보\n확장됨\n\n제주시 조천읍에 위치한 66년 전통 시원한 국물의 함덕밀면 ...
# 1558  상세정보\n확장됨\n\n함덕쉼팡은 2017년 호텔신라의 레시피 전수와 리모델링 지원...
# 1559  상세정보\n확장됨\n\n한돈과 한우를 참숯불에 즐길 수 있는 정육식당\n\n제주공항...
# 1560  상세정보\n확장됨\n함덕에 위치한 유기농 전문 카페 함덕카페h.\n농업법인 한스에서...
# 1561  상세정보\n확장됨\n\n제주의 재료를 사용하여 만든 라면 한 그릇\n\n해물라면오빠...
# 1562  상세정보\n확장됨\n\n마라도에서 3대 째 해녀를 이어온 집이다.\n싱싱한 해산물과...
# 1563  상세정보\n확장됨\n\n제주산 청정 재료를 이용한 해녀김밥, 전복해물라면\n\n제주...
# 1564  상세정보\n확장됨\n\n비양도에서 직접 채집하여 만든 해물요리 전문점\n\n제주시 ...
# 1565  상세정보\n확장됨\n\n카페 해뜰은 성산일출봉 옆에 자리한 카페로 2층은 실내, 3...
# 1566  상세정보\n확장됨\n\n육류와 해산물 모두 즐길 수 있는 해마루\n\n해물뚝배기, ...
# 1567  상세정보\n확장됨\n\n저렴한 가격에 제주도 흑돼지를 즐길 수 있는 켄싱턴 리조트 ...
# 1568  상세정보\n확장됨\n\n해녀들의 쉼터였던 불턱자리에 위치한 카페\n\n서귀포시 표선...
# 1569  상세정보\n확장됨\n\n해성도뚜리는 2015년 호텔신라의 레시피 전수와 리모델링 지...
# 1570  상세정보\n확장됨\n\n푸른 바다가 보이는 우도의 맛집으로   회뿐만 아니라 해물뚝...
# 1571  상세정보\n확장됨\n함덕 해수욕장 근처에 위치한 찜 요리 전문점이다.\n대표 메뉴는...
# 1572  상세정보\n확장됨\n\n제주도 멜젓에 찍어먹는 흑돼지의 맛\n\n섭지코지와 가까운 ...
# 1573  상세정보\n확장됨\n\n추자항에서 가까운 생선요리 전문점이다. 싱싱한 해산물과 생선...
# 1574  상세정보\n확장됨\n\n제주산 보말과 성게만을 사용한 식당\n\n중문관광단지 인근에...
# 1575  상세정보\n확장됨\n\n식사소반과 고기소반의 한식전문점\n\n제주 영어교육도시에 위...
# 1576  상세정보\n확장됨\n\n행복맛집은 2015년 호텔신라의 레시피 전수와 리모델링 지원...
# 1577  상세정보\n확장됨\n\n옛날 파라다이스 호텔로 활용되었던 공간 중 일부를 수리해 2...
# 1578  상세정보\n확장됨\n\n제주도는 세계적인 녹차산지로 유명하지만 허브를 재배하기에도 ...
# 1579  상세정보\n확장됨\n\n헬로키티아일랜드 내 헬로키티를 주제로한 테마카페\n\n서귀포...
# 1580  상세정보\n확장됨\n\n현경시장은 제주 보성시장 내 순대국밥 식당들 사이에 위치하고...
# 1581  상세정보\n확장됨\n\n집에서 직접 담근 된장으로 된장찌개를 조리하고, 직접 재배한...
# 1582  상세정보\n확장됨\n\n불고기와 비빔국수의 매콤달콤한 조화\n\n협재해수욕장 인근에...
# 1583  상세정보\n확장됨\n\n섭지코지 인근에 위치한 향토음식 전문점\n\n제주의 대표 관...
# 1584  상세정보\n확장됨\n\n협재 해수욕장 인근에 위치한 보말칼국수 맛집\n\n협재 해수...
# 1585  상세정보\n확장됨\n\n흑돼지를 연탄불에 천천히 구워내는 근고기전문점\n\n제주시 ...
# 1586  상세정보\n확장됨\n\n혜자분식은 2019년 호텔신라의 레시피 전수와 리모델링 지원...
# 1587  상세정보\n확장됨\n\n함덕해수욕장 주변 마을 골목에 있는 식당.\n'호끌락'은 제...
# 1588  상세정보\n확장됨\n\n서귀포 법환동에 위치한 호도제과는 고객의 건강과 믿음을 기본...
# 1589  상세정보\n확장됨\n\n소박하고 정갈한 분위기에서 즐기는 해장국\n\n성산일출봉에서...
# 1590  상세정보\n확장됨\n\n연탄불로 굽는 고기의 맛이 일품인 식당\n\n모든 육수를 흑...
# 1591  상세정보\n확장됨\n\n참숯에 구운 제주산 흑돼지를 홍삼진액을 찍어먹는 흑돼지 전문...
# 1592  상세정보\n확장됨\n\n식사가 가능한 이색카페\n\n아름다운 제주의 해안도로 명소로...
# 1593  상세정보\n확장됨\n\n월마트 내에 위치한 쌀식빵이 유명한 베이커리 \n\n뉴월드마...
# 1594  상세정보\n확장됨\n\n톳이 들어간 면발로 만든 담백한 해물 짜장면과 얼큰한 해물짬...
# 1595  상세정보\n확장됨\n\n맑고 깔끔한 국물의 흑돼지 맑은곰탕전문점\n\n협재해수욕장 ...
# 1596  상세정보\n확장됨\n\n추자도에서 단체석이 구비되어 있는 음식점으로, 추자에서 제주...
# 1597  상세정보\n확장됨\n\n다양한 초밥들을 맛 볼 수 있는 초밥집\n\n제주시 노형동에...
# 1598  상세정보\n확장됨\n\n활어회가 인기인 100% 자연산 활어회 포장 전문 횟집.\n...
# 1599  상세정보\n확장됨\n\n향토음식 맛과 전통을 이어가고자 2대째 운영중인 제주 향토음...
# 1600  상세정보\n확장됨\n\n국물이 진하고 든든한 왕갈비탕 전문점\n\n제주시 노형동에 ...
# 1601  상세정보\n확장됨\n\n계절재료를 사용한 차돌해물짬뽕과 해물간짜장\n\n조천읍 조천...
# 1602  상세정보\n확장됨\n\n1940년대에 지어진 구옥에서 즐기는 한상정식\n\n함덕해수...
# 1603  상세정보\n확장됨\n\n정겹고 옛스러운 느낌의 한식전문점\n\n제주시 봉개동에 위치...
# 1604  상세정보\n확장됨\n\n신선 재료를 사용하여 식감 또한 깔끔한 샤브샤브를 저렴한 가...
# 1605  상세정보\n확장됨\n\n신선한 제철회와 딱새우회를 만나볼 수 있는 곳\n\n제주시 ...
# 1606  상세정보\n확장됨\n\n분위기, 맛 모두 잡은 비주얼 카페\n\n안덕면에 위치한 휴...
# 1607  상세정보\n확장됨\n\n황금무지개는 언제나 신선한 재료만을 선별하여 모든 음식에 정...
# 1608  상세정보\n확장됨\n\n숙종이 보양식으로 즐겨먹은 흑염소\n\n흑염소농장과 직영점을...
